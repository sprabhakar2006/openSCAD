# %%
from openscad1 import *
set_printoptions(suppress=True)
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# example of surf_extrude
t0=time.time()

sec2=cr(pts1([[-25,0],[10,5,5],[10,-3,10],[10,5,5],[10,-8,7],[10,1]]),10)  
path2=cytz(cr(pts1([[-35,5,0],[10,8,20],[20,-5,10],[20,8,20],[10,-9,20],[10,1,0]]),10))
surf2=surf_extrude(sec2,path2)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
for(p={surf2})points(p,.2);

''') 
t1=time.time()
total=t1-t0
total
# Out:
# 1.1688809394836426

# %%
# example of surf_extrudef
t0=time.time()

sec2=cr(pts1([[-25,0],[10,5,5],[10,-3,10],[10,5,5],[10,-8,7],[10,1]]),10)  
path2=cytz(cr(pts1([[-35,5,0],[10,8,20],[20,-5,10],[20,8,20],[10,-9,20],[10,1,0]]),10))
surf2=surf_extrude(sec2,path2)
surf3=surf_extrudef(surf2,t=-1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
{swp(surf3)}

''') 
t1=time.time()
total=t1-t0
total
# Out:
# 1.1941320896148682

# %%
# example of function fillet_2cir

fillet=fillet_2cir(r1=5,r2=3,c1=[0,0],c2=[7,0],r=1)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
# %p_line({circle(5)},.2);
    # %p_line({circle(3,[7,0])},.2);
    p_line({fillet},.2);

''')

# %%
# example of function filleto_2cir and arc_long_2p

fillet=filleto_2cir(r1=10,r2=10,c1=[0,0],c2=[20,0],r=10)
p0,p1,p2,p3=fillet[1][len(fillet[1])-1], fillet[0][0],fillet[0][len(fillet[0])-1],fillet[1][0]
cir1=arc_long_2p(p0,p1,10,-1,40)
cir2=arc_long_2p(p2,p3,10,-1,40)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
    //%p_line({circle(10)},.2);
    //%p_line({circle(10,[20,0])},.2);
    color("blue")p_lineo({fillet[0]},.2);
    color("yellow")p_lineo({fillet[1]},.2);
    color("magenta")p_lineo({cir1},.2);
    color("cyan")p_lineo({cir2},.2);
    
    
''')

# %%
# example of function rm(theta)

line=[[0,0],[5,3]]
line1=array(line)@rm(30)
line1=line1.tolist()

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("yellow")p_lineo({line},.1); // original line
color("blue")p_lineo({line1},.1); // line rotated by 30 degrees

  
''')

# %%
# example of function cr(pl,s)

sec=cr(pl=[[0,0,.5],[10,0,2],[7,15,1]],s=5)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 
    
    
''')

# %%
# example of function translate(p,sec)

sec=cr([[0,0,.5],[10,0,2],[7,15,1]],5)
sec1=translate(p=[2,5,3],sec=sec)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 
color("magenta")p_line3dc({sec1},.1);
    
    
''')

# %%
# example of function scl2d(sec,sl)

sec=cr([[0,0,.5],[10,0,2],[7,15,1]],5)
sec1=scl2d(sec,.7)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 
color("magenta")p_line({sec1},.1);
    
    
''')

# %%
# example of function scl2d_c(sec,sl)

sec=cr([[0,0,.5],[10,0,2],[7,15,1]],5)
sec1=scl2d_c(sec,.7)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 
color("magenta")p_line({sec1},.1);
    
    
''')

# %%
# example of function scl3d(p,s)

sec=circle(10);
path=cr(pts1([[2,0],[-2,0,2],[0,10,3],[-3,0]]),5)
sol=prism(sec,path)
sol1=scl3d(sol,.7)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
# %{swp(sol)}
{swp(sol1)}
    
    
''')

# %%
# example of function ip(prism,prism1)

sec=circle(10)
path=cr(pts1([[2,0],[-2,0,2],[0,10,3],[-9.9,0]]),5)
p_0=prism(sec,path)
p_1=cylinder(r=3,h=15,s=30)
ip_1=ip(p_0,p_1)

   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
# %{swp(p_0)}
# %{swp(p_1)}
color("magenta")points({ip_1},.2);
color("blue")for(p={cpo(p_0)})p_line3d(p,.05);    
color("blue")for(p={cpo(p_1)})p_line3d(p,.05);
''')

# %%
# example of function tctp(r1,r2,cp1,cp2)
cir1=circle(10)
cir2=circle(5,[15,6])
sec=tctp(r1=10,r2=5,cp1=[0,0],cp2=[15,6]);

   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
p_line({cir1},.1);
p_line({cir2},.1);
color("blue")p_line({sec},.1);
    
    
''')

# %%
# example of function tctpf(r1,r2,cp1,cp2)
cir1=circle(10)
cir2=circle(5,[15,6])
sec=tctpf(r1=10,r2=5,cp1=[0,0],cp2=[15,6])

   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
p_line({cir1},.1);
p_line({cir2},.1);
color("blue")p_line({sec},.1);
    
    
''')

# %%
# example of function fillet_surf2sol(surf1,sol1,r,s,o)

t0=time.time()

sec1=arc(20,0,359,s=150)
path1=[[0,0],[-5,25]]

surf1=prism(sec1,path1)

sec2=cr(pts1([[-25,0],[10,5,5],[10,-3,10],[10,5,5],[10,-8,7],[10,1]]),10)  
path2=cytz(cr(pts1([[-35,5,0],[10,8,20],[20,-5,10],[20,8,20],[10,-9,20],[10,1,0]]),10))
surf2=surf_extrude(sec2,path2)

p=fillet_surf2sol(surf2,surf1,2,10,0)
p1=fillet_surf2sol(surf2,surf1,2,10,1)
p2=fillet_surf2sol(flip(surf2),surf1,2,10,1)
p3=fillet_surf2sol(flip(surf2),surf1,2,10,0)



with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
// when option is set to '0'
# %{swp(surf1)}
# %{swp(surf_extrudef(surf2,-.05))}
{swp_c(p)}
color("blue")translate([0,0,30])rotate([90,0,0])linear_extrude(.3)text("when option is set to '0' fillet is drawn outside",1.5);

// when option is set to '1'
translate([0,70,0]){{
# %{swp(surf1)}
# %{swp(surf_extrudef(surf2,-.05))}
{swp_c(p1)}
}}
color("blue")translate([0,70,30])rotate([90,0,0])linear_extrude(.3)text("when option is set to '1' fillet is drawn inside",1.5);

// when the surface first is flipped and option is set to '1'
translate([100,70,0]){{
# %{swp(surf1)}
# %{swp(surf_extrudef(surf2,-.05))}
{swp_c(p2)}
}}
color("blue")translate([100,70,30])rotate([90,0,0])linear_extrude(.3)text("when surface is fliiped and option is set to '1' fillet is drawn on reverse direction outside",1.5);


// when the surface first is flipped and option is set to '0'
translate([100,0,0]){{
# %{swp(surf1)}
# %{swp(surf_extrudef(surf2,-.05))}
{swp_c(p3)}
}}
color("blue")translate([100,0,30])rotate([90,0,0])linear_extrude(.3)text("when surface is fliiped and option is set to '0' fillet is drawn on reverse direction inside",1.5);

''') 
t1=time.time()
total=t1-t0
total
# Out:
# 4.348493814468384

# %%
# example of function fillet_sol2sol(surf1,sol1,r,s,o)

t0=time.time()

sec=circle(10)
path=cr(pts1([[2,0],[-2,0,2],[0,10,3],[-9.9,0]]),5)
p=prism(sec,path)
p1=cylinder(r=5,h=15,s=30)
fillet1=fillet_sol2sol(p,p1,2,10,0)
fillet2=fillet_sol2sol(p,p1,2,10,1)
fillet3=fillet_sol2sol(flip(p),p1,2,10,1)
fillet4=fillet_sol2sol(flip(p),p1,2,10,0)



with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
// when option is set to '0'
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet1)}
color("blue")translate([0,0,20])rotate([90,0,0])linear_extrude(.3)text("when option is set to '0' fillet is drawn outside",1.5);

// when option is set to '1'
translate([0,70,0]){{
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet2)}
}}
color("blue")translate([0,70,20])rotate([90,0,0])linear_extrude(.3)text("when option is set to '1' fillet is drawn inside",1.5);

// when the surface first is flipped and option is set to '1'
translate([100,70,0]){{
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet3)}
}}
color("blue")translate([100,70,20])rotate([90,0,0])linear_extrude(.3)text("when surface is fliiped and option is set to '1' fillet is drawn on reverse direction outside",1.5);


// when the surface first is flipped and option is set to '0'
translate([100,0,0]){{
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet4)}
}}
color("blue")translate([100,0,20])rotate([90,0,0])linear_extrude(.3)text("when surface is fliiped and option is set to '0' fillet is drawn on reverse direction inside",1.5);

''') 
t1=time.time()
total=t1-t0
total
# Out:
# 0.5310211181640625

# %%
# example of function ipf(prism,prism1,r,s,o=0)

t0=time.time()

sec=circle(10)
path=cr(pts1([[2,0],[-2,0,2],[0,10,3],[-9.9,0]]),5)
p=prism(sec,path)
p1=cylinder(r=5,h=15,s=30)
fillet1=ipf(p,p1,2,10,0)
fillet2=ipf(p,p1,2,10,1)
fillet3=ipf(p,flip(p1),2,10,1)
fillet4=ipf(p,flip(p1),2,10,0)



with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
// when option is set to '0'
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet1)}
color("blue")translate([0,0,20])rotate([90,0,0])linear_extrude(.3)text("when option is set to '0' fillet is drawn outside",1.5);

// when option is set to '1'
translate([0,70,0]){{
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet2)}
}}
color("blue")translate([0,70,20])rotate([90,0,0])linear_extrude(.3)text("when option is set to '1' fillet is drawn inside",1.5);

// when the surface first is flipped and option is set to '1'
translate([100,70,0]){{
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet3)}
}}
color("blue")translate([100,70,20])rotate([90,0,0])linear_extrude(.3)text("when intersecting prism 'p1' is flipped and option is set to '1' fillet is drawn on reverse direction outside",1.5);


// when the surface first is flipped and option is set to '0'
translate([100,0,0]){{
# %{swp(p)}
# %{swp(p1)}
{swp_c(fillet4)}
}}
color("blue")translate([100,0,20])rotate([90,0,0])linear_extrude(.3)text("when intersecting prism 'p1' is flipped and option is set to '0' fillet is drawn on reverse direction inside",1.5);

''') 
t1=time.time()
total=t1-t0
total
# Out:
# 0.5527780055999756

# %%
# example of function multiple_sec_extrude(path_points=[],radiuses_list=[],sections_list=[],option=0,s=10)

sec1=circle(10)
sec2=square(5,True)
sec3=cr(pts1([[-3.5,-2.5,3],[7,0,3],[0,5,3],[-7,0,3]]))
sections=[sec1,sec2,sec3,sec1,sec3]
path=array([[0,0,0],[20,2,5],[-7,25,3],[5,10,30],[-30,15,3]]).cumsum(0)
r=[0,5,7,12,0]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
color("blue")for(p={multiple_sec_extrude(path,r,sections,0,20)})p_line3dc(p,.1);
{swp(multiple_sec_extrude(path,r,sections,0,20))}
    ''')

# %%
# example of function path_extrude(sec,path)

sec=cr(pts1([[0,0,.2],[3,0,.2],[0,2,.2],[-3,0,.2]]),10)
path=helix(10,5,4,5)
sol=path_extrude(sec,path)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
{swp(sol)}
    ''')

# %%
# example of function path_extrudec(sec,path)

sec=cr(pts1([[0,0,.2],[3,0,.2],[0,2,.2],[-3,0,.2]]),10)
path=c2t3(circle(10))
sol=path_extrudec(sec,path)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
{swp_c(sol)}
    ''')

# %%
# example of function cylinder(r1=1,r2=1,h=1,cp=[0,0],s=50,r=0,d=0,d1=0,d2=0,center=False) and function swp

sol=cylinder(r1=10,r2=5,h=20)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
{swp(sol)}
    ''')

# %%
# example of function bezier(p,s=10)

control_points=array([[0,0,0],[10,5,5],[0,20,20],[-10,5,15],[0,0,10]]).cumsum(0).tolist()
curve=bezier(control_points,50)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
color("blue")points({curve},.2);
// control points
color("magenta")points({control_points},.5);
color("cyan")p_line3d({control_points},.05);
    ''')
control_points
# Out:
# [[0, 0, 0], [10, 5, 5], [10, 25, 25], [0, 30, 40], [0, 30, 50]]

# %%
# example of function arc_3d(v=[0,0,1],r=1,theta1=0,theta2=360,cw=-1,s=50)
vector=[[0,0,0],[2,5,10]]
arc1=arc_3d(v=[2,5,10],r=3,theta1=0,theta2=90,cw=-1,s=50)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
//arc
color("blue")p_line3d({arc1},.1);
// vector
color("cyan")p_line3d({vector},.1);

    ''')

# %%
# example of function plane(nv,radius)

vector=[[0,0,0],[2,5,10]]
plane1=plane(nv=[2,5,10],radius=10)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

//plane
# %{swp(plane1)}

// vector
color("magenta")p_line3d({vector},.1);

    ''')

# %%
#  example of function c_hull(pnt)
a=random.random(1000)*(20-5)+5
b=random.random(1000)*(30-10)+10
points=array([a,b]).transpose(1,0).tolist()
convex_hull=c_hull(points)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

points({points},.2);
color("blue")p_line({convex_hull},.05);

    ''')

# %%
# example of function convex(sec)
sec1=cr_c(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
sec2=cr_c(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// not a convex section
color("blue")p_line({sec1},.05);

//convex section
color("magenta")translate([20,0,0])p_line({sec2},.05);

    ''')
convex(sec1),convex(sec2)
# Out:
# (False, True)

# %%
# example of function cir_p_t(cir,pnt)
cir=c3t2(translate([20,10,0],circle(10)))
point=[3,5]
tangent_point=cir_p_t(cir,point)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
// "cyan" is the tangent point from circle to some external point ("magenta color")
# %p_line({cir},.1);
color("magenta")points({[point]},.5);
color("cyan")points({[tangent_point]},.5);
color("blue")p_line({[point,tangent_point]},.05);
    ''')

# %%
# example of function concave_hull(pnts,x=1,loops=10)
t0=time.time()
a=random.random(1000)*(20-5)+5
b=random.random(1000)*(30-10)+10
points=array([a,b]).transpose(1,0).tolist()
conc_hull=concave_hull(points,2)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

points({points},.2);
color("blue")p_line({conc_hull},.05);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.6727471351623535

# %%
# example of function path_offset(path,d)

path=cr(pts1([[-5,0],[5,0,2],[-1,10,2],[-5,0]]))
path1=path_offset(path,-1)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
// orginal path
color("blue")p_lineo({path},.05);
//offset path
color("magenta")p_lineo({path1},.05);


    ''')

# %%
# example of function pntsnfaces(bead2)

path=cr(pts1([[-5,0],[5,0,2],[-1,10,2],[-5,0]]))
path1=path_offset(path,-1)
final_path=path+flip(path1)
sec=circle(10)
sol=prism(sec,final_path)

points, faces=pntsnfaces(sol)[0],pntsnfaces(sol)[1]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

polyhedron({points},{faces},convexity=10);
    ''')

# %%
# example of function offset_points(sec,r)
t0=time.time()
sec=cr_c(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
sec1=offset_points(sec,2)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


//original points
points({sec},.2);

// offset points
color("blue") points({sec1},.2);


    ''')
t1=time.time()
t1-t0
# Out:
# 0.00982809066772461

# %%
# example of function offset_pointsv(sec,r)
t0=time.time()
sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
sec1=offset_pointsv(sec,2)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


//original points
points({sec},.2);

// offset points
color("blue") points({sec1},.2);


    ''')
t1=time.time()
t1-t0
# Out:
# 0.009557008743286133

# %%
# example of function convert_secv(sec)
t0=time.time()
sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
sec1=convert_secv(sec)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


//original sec
p_line({sec},.2);

// converted sec
color("blue") p_line({sec1},.08);


    ''')
t1=time.time()
t1-t0
# Out:
# 0.03472113609313965

# %%
set_printoptions(suppress=True)

# %%
# example of function s_int(s)
t0=time.time()
sec=cr(pts1([[0,0,.1],[7,5,2],[-7,10,2]]),3)
sec1=offset_segv(sec,-1)
self_intersections=s_int(sec1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// line segments
color("blue") for (p={sec1}) p_line(p,.05);

// intersection points
color("magenta")points({self_intersections},.2);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.016559123992919922

# %%
# example of function s_int(s)
t0=time.time()
sec=cr(pts1([[0,0,2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),5)
sec=seg(sec)
s=s_int(sec)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// line segments
color("blue") for (p={sec}) p_line(p,.05);

// intersection points
color("magenta")points({s},.4);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.028871774673461914

# %%
#  example of function s_int1(s)
t0=time.time()
sec=offset_segv([[0,0],[10,0],[15,7]],-1)
self_intersections=s_int1(sec)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// line segments
color("blue") for (p={sec}) p_line(p,.05);

// intersection points
color("magenta")points({self_intersections},.4);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.0041561126708984375

# %%
#  example of function offset_seg_cw(sec,r)
t0=time.time()
sec=sec=cr(pts1([[0,0,2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),5)
sec1=offset_seg_cw(sec,-2)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// original section
color("blue") points({sec},.2);

// offset segments
color("magenta")points({sec1},.2);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.015210866928100586

# %%
#  example of function offset_segv(sec,r)
t0=time.time()
sec=sec=cr(pts1([[0,0,2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),5)
sec1=offset_segv(sec,-1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// original section
color("blue") points({sec},.2);

// offset segments
color("magenta")for(p={sec1})points(p,.2);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.010230064392089844

# %%
#  example of another method to offset segment where points are clockwise and example function cwv(sec)
t0=time.time()
sec=cr(pts1([[0,0,2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),5)
sec0=seg(sec)
decision=cwv(sec)
sec1=[path_offset(sec0[i],-2) for i in range(len(sec0)) if decision[i]==1]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

// original section
color("blue") points({sec},.2);

// offset segments
color("magenta")for(p={sec1})points(p,.2);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.01665210723876953

# %%
#  example of function sort_pointsv(sec,sec1)
t0=time.time()
sec=circle(10)
sec1=cr(pts1([[-2.5,-2.5,1],[5,0,1],[0,5,1],[-5,0,1]]))
sec2=sort_pointsv(sec,sec1)
sec3=cpo([sec2,sec])
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

p_line({sec},.05);
p_line({sec2},.05);
color("blue") for(p={sec3})p_line(p,.1);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.011275053024291992

# %%
#  example of function sort_points(sec,sec1)
t0=time.time()
sec=circle(10)
sec1=cr(pts1([[-2.5,-2.5,1],[5,0,1],[0,5,1],[-5,0,1]]))
sec2=sort_points(sec,sec1)
sec3=cpo([sec2,sec])
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

p_line({sec},.05);
p_line({sec2},.05);
color("blue") for(p={sec3})p_line(p,.1);

    ''')
t1=time.time()
t1-t0
# Out:
# 0.011162996292114258

# %%
# example of function surf_offset(surf,o)

sec=circle(10);
path=cr(pts1([[2,0],[-2,0,2],[0,10,3],[-3,0]]),5)
sol=prism(sec,path)
sol1=surf_offset(sol,-1)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
# %{swp_c(sol)}
{swp_c(sol1)}
    
    
''')

# %%
# example of function pts1(p)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.05);
    
    
''')

# %%
# example of function m_points(sec,sl=20)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sec1=m_points(sec,1)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

// original closed section 'sec'
color("blue")translate([0,10,0]) points({sec},.2);

// points at every 1 mm distance in each straight line segment of 'sec'
color("magenta")points({sec1},.2);
    
''')

# %%
# example of function m_points_o(sec,sl=20)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sec1=m_points_o(sec,1)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

// original closed section 'sec'
color("blue")
{{points({sec},.2);
p_lineo({sec},.05);}}

// points at every 1 mm distance in each straight line segment of 'sec'
color("magenta")
{{translate([0,10,0])points({sec1},.2);
translate([0,10,0]) p_lineo({sec1},.05);}}
    
''')

# %%
# example of function arc_2p(p1,p2,r,cw=1,s=20)

p1=[2,0]
p2=[0,2]
arc1=arc_2p(p1,p2,2,1,5)

arc2=arc_2p(p1,p2,2,-1,5)

   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

// arc clockwise
color("blue")
points({arc1},.2);

// arc counter clockwise
color("magenta")
points({arc2},.2);

    
''')

# %%
# example of function arc_long_2p(p1,p2,r,cw=1,s=20)

p1=[2,0]
p2=[0,2]
arc1=arc_long_2p(p1,p2,2,1,20)

arc2=arc_long_2p(p1,p2,2,-1,20)

   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

// arc clockwise
color("blue")
p_lineo({arc1},.05);

// arc counter clockwise
color("magenta")
p_lineo({arc2},.05);

    
''')

# %%
# example of function arc_2p_cp(p1,p2,r,cw=-1)

p1=[2,0]
p2=[0,2]
arc1=arc_2p(p1,p2,2,1,5)
cp1=arc_2p_cp(p1,p2,2,1)

arc2=arc_2p(p1,p2,2,-1,5)
cp2=arc_2p_cp(p1,p2,2,-1)

   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

// arc clockwise with center point of the arc
color("blue")
{{p_lineo({arc1},.05);
points({[cp1]},.2);}}

// arc counter clockwise with center point of the arc
color("magenta")
{{p_lineo({arc2},.05);
points({[cp2]},.2);}}
    
''')

# %%
# example of function offset(sec,r)

t0=time.time()


# sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),30)
sec=cr(pts1([[0,0,1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),10)
# sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),10)
# sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),10)
# sec=circle(10)
# sec=pts([[0,0],[10,0],[0,5],[-10,0]])

# path=cr(pts1([[2,0],[-2,0,2],[0,7,4.2],[-4.2,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,5.3],[-5.3,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,2],[-2,0]]),20)
os=linspace(-4.2,20,100)
sec1=[offset(sec,i) for i in os]
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

color("magenta")for(p={sec1})p_line(p,.05);
color("blue")p_line({sec},.1);

''') 
t1=time.time()
t1-t0
# Out:
# 0.9667189121246338

# %%
# example of function prism(sec,path) and function swp_prism_h(prism_big, prism_small)
t0=time.time()
# sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=cr(pts1([[0,0,1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),20)
# sec=pts([[0,0],[10,0],[0,5],[-10,0]])
# path=cr(pts1([[2,0],[-2,0,2],[0,7,4.2],[-4.2,0]]),20)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,5.2],[-5.2,0]]),20)
path=cr(pts1([[2,0],[-2,0,2],[0,7,2],[-2,0]]),20)


sol=prism(sec,path)
sol1=prism(sec,path_offset(path,-.5))
sol2=swp_prism_h(sol,sol1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''

{swp(sol)}
  
''') 

t1=time.time()
t1-t0
# Out:
# 1.6262738704681396

# %%
# example of function p_cir_t(pnt,cir)
cir=c3t2(translate([20,10,0],circle(10)))
point=[3,5]
tangent_point=p_cir_t(point,cir)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

# %p_line({cir},.1);
color("magenta")points({[point]},.5);
color("cyan")points({[tangent_point]},.5);
# %p_line({[point,tangent_point]},.05);
    ''')

# %%
# example of function v_sec_extrude(sec,path,o)
sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),10)
path=helix(20,15,1,5)
sol=v_sec_extrude(sec,path,-2)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

{swp(sol)}
    ''')

# %%
# example of function t_cir_tarc(r1,r2,cp1,cp2,r,s=50)

r=(10+5+linalg.norm([5,4]))/2+.1
arc1=t_cir_tarc(10,5,[0,0],[5,-4],r,20)
c1=circle(10)
c2=circle(5,[5,-4])
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

# %p_line({c1},.05);
# %p_line({c2},.05);
color("blue") p_lineo({arc1},.05);



    ''')

# %%
# example of function tcct(r1,r2,cp1,cp2,cw=-1)
c1=circle(10)
c2=circle(5,[15,-8])

line= tcct(10,5,[0,0],[15,-8],cw=-1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

# %p_line({c1},.05);
# %p_line({c2},.05);
color("blue") p_lineo({line},.05);



    ''')

# %%
# example of function arc_3p(p1,p2,p3,s=30)

p1,p2,p3=[3,0],[0,0],[0,3]
arc1=arc_3p(p1,p2,p3)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


color("blue") p_lineo({arc1},.05);
points({[p1,p2,p3]},.2);
    ''')

# %%
# example of function cir_3p(p1,p2,p3,s=30)

p1,p2,p3=[3,0],[0,0],[0,3]
cir=cir_3p(p1,p2,p3,30)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


color("blue") p_line({cir},.05);
points({[p1,p2,p3]},.2);
    ''')

# %%
# example of function cp_3p(p1,p2,p3)

p1,p2,p3=[3,0],[0,0],[0,3]
cir=cir_3p(p1,p2,p3,30)
center= cp_3p(p1,p2,p3)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


color("blue") p_line({cir},.05);
points({[p1,p2,p3]},.2);
color("magenta")points({[center]},.2);
    ''')

# %%
# example of function pies1(sec,pnts)
t0=time.time()
a=random.random(10000)*(20-(-5))+(-5)
b=random.random(10000)*(25-(-2))+(-2)
points=array([a,b]).transpose(1,0).tolist()
sec=cr(pts1([[2,1,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


color("blue") p_line({sec},.05);
points({points},.2);
color("magenta")points({pies1(sec,points)},.2);
    ''')
t1=time.time()
t1-t0
# Out:
# 0.17818880081176758

# %%
# example of function swp_prism_h(prism_big,prism_small)

sec1=circle(10)
path=cr(pts1([[2,0],[-2,0,2],[0,10,3],[-3,0]]),5)
sol=prism(sec1,path)
sol1=surf_offset(sol,-1)
sol2=swp_prism_h(sol,sol1)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

{swp_c(sol2)}
    
    
''')

# %%
# example of function surf_base(surf,h)
t0=time.time()

sec2=cr(pts1([[-25,0],[10,5,5],[10,-3,10],[10,5,5],[10,-8,7],[10,1]]),10)  
path2=cytz(cr(pts1([[-35,5,0],[10,8,20],[20,-5,10],[20,8,20],[10,-9,20],[10,1,0]]),10))
surf2=surf_extrude(sec2,path2)
sol=surf_base(surf2,0)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

{swp(sol)}

''') 
t1=time.time()
total=t1-t0
total
# Out:
# 1.2058770656585693

# %%
# example of function helix(radius=10,pitch=10, number_of_coils=1, step_angle=1)

path=helix(10,5,10,5)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
p_line3d({path},1,$fn=20);
    ''')

# %%
# example of function offset_points_cw(sec,r)

sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),20)

# path=cr(pts1([[2,0],[-2,0,2],[0,7,4.2],[-4.2,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,5.3],[-5.3,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,2],[-2,0]]),20)


offsetPoints=offset_points_cw(sec,-2)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")points({sec},.2);
color("magenta")points({offsetPoints},.2);
  
''')

# %%
# example of function offset_points_ccw(sec,r)

sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),20)

# path=cr(pts1([[2,0],[-2,0,2],[0,7,4.2],[-4.2,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,5.3],[-5.3,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,2],[-2,0]]),20)


offsetPoints=offset_points_ccw(sec,2)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")points({sec},.2);
color("magenta")points({offsetPoints},.2);
  
''')

# %%
# example of function cpo(prism)

sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),20)

path=cr(pts1([[2,0],[-2,0,2],[0,7,4.2],[-4.2,0]]),20)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,5.3],[-5.3,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,2],[-2,0]]),20)

sp1=translate([0,50,0],sphere(10))
sp2=translate([30,0,0],cpo(sp1))


sol=prism(sec,path)
sol1=translate([20,0,0],cpo(sol))

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

color("blue")for(p={sol})p_line3dc(p,.05);
color("magenta")for(p={sol1})p_line3d(p,.05);

color("blue")for(p={sp1})p_line3dc(p,.05);
color("magenta")for(p={sp2})p_line3d(p,.05);

''')

# %%
# example of function fillet_3p_3d(p0,p1,p2,r,s)

p1,p2,p3=[[3,0,0],[0,0,0],[0,3,3]]
fillet=fillet_3p_3d(p1,p2,p3,3,10)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

color("blue")p_line3dc({fillet},.05);


''')

# %%
# example of function fillet_3p_3d_cp(p0,p1,p2,r)

p1,p2,p3=[[3,0,0],[0,0,0],[0,3,3]]
fillet=fillet_3p_3d(p1,p2,p3,3,10)
centerPoint=fillet_3p_3d_cp(p1,p2,p3,3)


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

color("blue")p_line3dc({fillet},.05);
color("magenta")points({[centerPoint]},.2);


''')

# %%
# example of function arc_3p_3d(points,s)

p1,p2,p3=[[3,0,0],[0,0,0],[2,4,3]]
arc1=arc_3p_3d([p1,p2,p3],30)



with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

color("magenta")p_line3d({arc1},.05);
color("blue")points({[p1,p2,p3]},.2);


''')

# %%
# example of function cir_3p_3d(points,s)

p1,p2,p3=[[3,0,0],[0,0,0],[0,3,2]]
cir=cir_3p_3d([p1,p2,p3],50)



with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

color("magenta")p_line3dc({cir},.05);
color("blue")points({[p1,p2,p3]},.2);


''')

# %%
# example of function m_points1(sec,sl=20)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sec1=m_points1(sec,5)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

// original closed section 'sec'
color("blue")points({sec},.2);

// 5 points in each straight line segment of 'sec'
color("magenta")translate([0,10,0])points({sec1},.2);
    
''')

# %%
# example of function linear_extrude(sec,h=1,a=0,steps=1)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sol=linear_extrude(sec,50,360,50)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

color("magenta") for(p={sol})p_line3dc(p,.05);
# %{swp(sol)}
    
''')

# %%
# example of function rsz3d(prism,rsz)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sol=translate([-5,0,0],linear_extrude(sec,10))
sol1=rsz3d(sol,[5,6,7])
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

# %{swp(sol)}
{swp(sol1)}
    
''')

# %%
# example of function rsz3dc(prism,rsz)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sol=translate([-5,0,0],linear_extrude(sec,10))
sol1=rsz3dc(sol,[5,6,7])
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

# %{swp(sol)}
{swp(sol1)}
    
''')

# %%
# example of function bb(prism)

sec=cr(pts1([[0,0,1],[10,0,1],[0,5,1],[-10,0,1]]),5)
sol=translate([-5,0,0],linear_extrude(sec,10))
dim=bb(sol)
sol1=rsz3dc(sol,array(dim)-[1,1,1])
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

# %{swp(sol)}
{swp(sol1)}
    
''')

# %%
# example of function cube(s,center=False)

sol=cube([5,4,7],False)
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

{swp(sol)}
    
''')

# %%
# example of function sphere(r=0,cp=[0,0,0],s=50)

sol=sphere(10,[15,15,10])
   
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

{swp(sol)}
    
''')

# %%
# example of function rsz2d(sec,rsz)

sec=cr([[0,0,.5],[10,0,2],[7,15,1]],5)
sec1=rsz2d(sec,[4,3])
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 
color("magenta")p_line({sec1},.1);
    
    
''')

# %%
# example of function rsz2dc(sec,rsz)

sec=cr([[0,0,.5],[10,0,2],[7,15,1]],5)
sec1=rsz2dc(sec,[4,3])
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 
color("magenta")p_line({sec1},.1);
    
    
''')

# %%
# explanation of process of creating fillet between intersection of 2 solids

sp1=sphere(10,s=30)
sp2=translate([7,7,7],sphere(5,s=30))

sp3=translate([7,7,7],q_rot(['y45','z45'],sphere(5,s=30)))
sp4=cpo(sp3)
ip1=ip_surf(sp1,sp3)

p,p1,r,s,o=sp1,sp3,2,10,0

pa=[[[[p[i][j],p[i][j+1],p[i+1][j]],[p[i+1][j+1],p[i+1][j],p[i][j+1]]] if j<len(p[0])-1 else \
     [[p[i][j],p[i][0],p[i+1][j]],[p[i+1][0],p[i+1][j],p[i][0]]] \
     for j in range(len(p[0]))] for i in range(len(p)-1)]
pa=array(pa).reshape(-1,3,3)

#     pb=[[[p1[i][j],p1[i+1][j]] for j in range(len(p1[0]))] for i in range(len(p1)-1)]
#     pb=array(pb).reshape(-1,2,3)
p2=cpo(p1)
pb=[[[p2[i][j],p2[i][j+1]] for j in range(len(p2[0])-1)] for i in range(len(p2))]
pb=array(pb).reshape(-1,2,3)

p01,p02,p03,p04,p05=pa[:,0],pa[:,1],pa[:,2],pb[:,0],pb[:,1]

v1,v2,v3=p05-p04,p02-p01,p03-p01
i,j=len(v1),len(v2)
#     array([(-v1).tolist()]*j).transpose(1,0,2).shape,array([v2]*i).shape,array([cross(v2,v3)]*i).shape,(p04[:,None]-p01).shape
#     cross(v3,-v1[:,None]).shape,cross(-v1[:,None],v2).shape
a=einsum('ijk,ijk->ij',array([cross(v2,v3)]*i),p04[:,None]-p01)
b=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t1=einsum('ij,ij->ij',a,b)

a=einsum('ijk,ijk->ij',cross(v3,-v1[:,None]),p04[:,None]-p01)
b=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t2=einsum('ij,ij->ij',a,b)

a=einsum('ijk,ijk->ij',cross(-v1[:,None],v2),p04[:,None]-p01)
b=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t3=einsum('ij,ij->ij',a,b)

condition=(t1>=0) & (t1<=1) & (t2>=0) & (t2<=1) & (t3>=0) & (t3<=1) & (t2+t3>=0) & (t2+t3<=1)
#     condition.shape

pnt1=(p04[:,None]+einsum('ijk,ij->ijk',array([v1]*j).transpose(1,0,2),t1))[condition]
#     pnt1.shape

uv1=v1/linalg.norm(v1,axis=1).reshape(-1,1)
uv1=array([uv1]*j).transpose(1,0,2)[condition]
#     uv1.shape
#     pnt2=pnt1+uv1*r

a=cross(v2,v3)
b=a/(linalg.norm(a,axis=1).reshape(-1,1)+.00001)
b=array([b]*i)[condition]
#     b.shape
normals=array([pnt1,pnt1+b*r]).transpose(1,0,2)
nxt_pnt=array(pnt1[1:].tolist()+[pnt1[0]])
v_rot=nxt_pnt-pnt1
rotation_axis=array([pnt1,pnt1+v_rot*.5]).transpose(1,0,2)
if o==0:
    cir=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,t)) for t in linspace(45,135,5)] for i in arange(len(pnt1))]).tolist()
else:
    cir=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,-t)) for t in linspace(45,135,5)] for i in arange(len(pnt1))]).tolist()

pc=array([[[cir[i][j],cir[i][j+1]]  for j in arange(len(cir[0])-1)] for i in arange(len(cir))]).reshape(-1,2,3)
#     pc.shape

p01,p02,p03,p04,p05=pa[:,0],pa[:,1],pa[:,2],pc[:,0],pc[:,1]

v1,v2,v3=p05-p04,p02-p01,p03-p01
i,j=len(v1),len(v2)

a1=einsum('ijk,ijk->ij',array([cross(v2,v3)]*i),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t1=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(v3,-v1[:,None]),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t2=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(-v1[:,None],v2),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t3=einsum('ij,ij->ij',a1,b1)

condition=(t1>=0) & (t1<=1) & (t2>=0) & (t2<=1) & (t3>=0) & (t3<=1) & (t2+t3>=0) & (t2+t3<=1)
#     condition.shape

pnt3=(p04[:,None]+einsum('ijk,ij->ijk',array([v1]*j).transpose(1,0,2),t1))[condition]
pnt3=sort_pointsv(pnt1,pnt3)

#     if o==0:
cir1=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,-t)) for t in linspace(-45,45,5)] for i in arange(len(pnt1))]).tolist()
#     else:
#         cir=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,t)) for t in linspace(-90,90,5)] for i in arange(len(pnt1))]).tolist()

pa=[[[[p1[i][j],p1[i][j+1],p1[i+1][j]],[p1[i+1][j+1],p1[i+1][j],p1[i][j+1]]] if j<len(p1[0])-1 else \
     [[p1[i][j],p1[i][0],p1[i+1][j]],[p1[i+1][0],p1[i+1][j],p1[i][0]]] \
     for j in range(len(p1[0]))] for i in range(len(p1)-1)]
pa=array(pa).reshape(-1,3,3)

pc=array([[[cir1[i][j],cir1[i][j+1]]  for j in arange(len(cir1[0])-1)] for i in arange(len(cir1))]).reshape(-1,2,3)

p01,p02,p03,p04,p05=pa[:,0],pa[:,1],pa[:,2],pc[:,0],pc[:,1]

v1,v2,v3=p05-p04,p02-p01,p03-p01
i,j=len(v1),len(v2)

a1=einsum('ijk,ijk->ij',array([cross(v2,v3)]*i),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t1=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(v3,-v1[:,None]),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t2=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(-v1[:,None],v2),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+[.00001,.00001,.00001]]*i)))
t3=einsum('ij,ij->ij',a1,b1)

condition=(t1>=0) & (t1<=1) & (t2>=0) & (t2<=1) & (t3>=0) & (t3<=1) & (t2+t3>=0) & (t2+t3<=1)
#     condition.shape

pnt2=(p04[:,None]+einsum('ijk,ij->ijk',array([v1]*j).transpose(1,0,2),t1))[condition]
pnt2=sort_pointsv(pnt1,pnt2)


sol=array([pnt3,pnt1,pnt2]).transpose(1,0,2)
sol=[fillet_3p_3d(p3,p2,p1,r_3p_3d([p1,p2,p3])*1.9,s) for (p1,p2,p3) in sol]
sol1=sol+[sol[0]]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
//explanation of the process of creating fillet:

//refer bigger sphere as sp1
//refer smaller sphere as sp2

//"Blue" points are the intersection points between sp1 and sp2
//"magenta" line at the normal drawn from the "Blue" points to sp1 surface
//"green" line arc is drawn with axis of rotation "navy blue" line to find the intersection point "green" with sp1. radius of the arc is the radius of the fillet
//"cyan" line arc drawn with axis of rotation "navy blue" line to find the intersection point "cyan" with sp2. radius of the arc is the radius of the fillet
//with 3 points "cyan", "blue" and "green" arcs are drawn to form fillets
    
include <dependencies2.scad>
for(p={sp1})p_line3dc(p,.02);
for(p={cpo(sp3)})p_line3d(p,.02);
color("blue")points({ip1},.3);
color("magenta")for(p={normals.tolist()})p_line3d(p,.05);
color("green")for(p={cir})p_line3d(p,.02);
color("green")points({pnt3},.2);
color("cyan")for(p={cir1})p_line3d(p,.02);
color("cyan")points({pnt2},.2);
color("navy")for(p={rotation_axis.tolist()})p_line3d(p,.05);
color("black")for(p={sol})p_line3dc(p,.02);

//%{swp(sp1)}
//%{swp(sp3)}
# %{swp(sol1)}
''')

# %%
# explanation of process of creating fillet between intersection of 2 solids

pl=translate([0,0,1],plane([0,0,1],25))
sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),10)
sol3=linear_extrude(m_points(sec,1),10)
ip1=ip_surf(pl,sol3)
sol2=fillet_surf2sol(flip(pl),sol3,1,10,0)

p,p1,r,s,o=flip(pl),sol3,1,10,0

pa=[[[[p[i][j],p[i][j+1],p[i+1][j]],[p[i+1][j+1],p[i+1][j],p[i][j+1]]] if j<len(p[0])-1 else \
     [[p[i][j],p[i][0],p[i+1][j]],[p[i+1][0],p[i+1][j],p[i][0]]] \
     for j in range(len(p[0])-1)] for i in range(len(p)-1)]
pa=array(pa).reshape(-1,3,3)

#     pb=[[[p1[i][j],p1[i+1][j]] for j in range(len(p1[0]))] for i in range(len(p1)-1)]
#     pb=array(pb).reshape(-1,2,3)
p2=cpo(p1)
pb=[[[p2[i][j],p2[i][j+1]] for j in range(len(p2[0])-1)] for i in range(len(p2))]
pb=array(pb).reshape(-1,2,3)

p01,p02,p03,p04,p05=pa[:,0],pa[:,1],pa[:,2],pb[:,0],pb[:,1]

v1,v2,v3=p05-p04,p02-p01,p03-p01
i,j=len(v1),len(v2)
#     array([(-v1).tolist()]*j).transpose(1,0,2).shape,array([v2]*i).shape,array([cross(v2,v3)]*i).shape,(p04[:,None]-p01).shape
#     cross(v3,-v1[:,None]).shape,cross(-v1[:,None],v2).shape
a=einsum('ijk,ijk->ij',array([cross(v2,v3)]*i),p04[:,None]-p01)
b=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t1=einsum('ij,ij->ij',a,b)

a=einsum('ijk,ijk->ij',cross(v3,-v1[:,None]),p04[:,None]-p01)
b=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t2=einsum('ij,ij->ij',a,b)

a=einsum('ijk,ijk->ij',cross(-v1[:,None],v2),p04[:,None]-p01)
b=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t3=einsum('ij,ij->ij',a,b)

condition=(t1>=0) & (t1<=1) & (t2>=0) & (t2<=1) & (t3>=0) & (t3<=1) & (t2+t3>=0) & (t2+t3<=1)
#     condition.shape

pnt1=(p04[:,None]+einsum('ijk,ij->ijk',array([v1]*j).transpose(1,0,2),t1))[condition]
#     pnt1.shape

uv1=v1/linalg.norm(v1,axis=1).reshape(-1,1)
uv1=array([uv1]*j).transpose(1,0,2)[condition]
#     uv1.shape
#     pnt2=pnt1+uv1*r

a=cross(v2,v3)
b=a/(linalg.norm(a,axis=1).reshape(-1,1)+.00001)
b=array([b]*i)[condition]
#     b.shape
normals=array([pnt1,pnt1+b*r]).transpose(1,0,2)
nxt_pnt=array(pnt1[1:].tolist()+[pnt1[0]])
v_rot=nxt_pnt-pnt1
rotation_axis=array([pnt1,pnt1+v_rot*.5]).transpose(1,0,2)
if o==0:
    cir=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,t)) for t in linspace(45,135,5)] for i in arange(len(pnt1))]).tolist()
else:
    cir=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,-t)) for t in linspace(45,135,5)] for i in arange(len(pnt1))]).tolist()

pc=array([[[cir[i][j],cir[i][j+1]]  for j in arange(len(cir[0])-1)] for i in arange(len(cir))]).reshape(-1,2,3)
#     pc.shape

p01,p02,p03,p04,p05=pa[:,0],pa[:,1],pa[:,2],pc[:,0],pc[:,1]

v1,v2,v3=p05-p04,p02-p01,p03-p01
i,j=len(v1),len(v2)

a1=einsum('ijk,ijk->ij',array([cross(v2,v3)]*i),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t1=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(v3,-v1[:,None]),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t2=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(-v1[:,None],v2),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t3=einsum('ij,ij->ij',a1,b1)

condition=(t1>=0) & (t1<=1) & (t2>=0) & (t2<=1) & (t3>=0) & (t3<=1) & (t2+t3>=0) & (t2+t3<=1)
#     condition.shape

pnt3=(p04[:,None]+einsum('ijk,ij->ijk',array([v1]*j).transpose(1,0,2),t1))[condition]
pnt3=sort_pointsv(pnt1,pnt3) if len(pnt3)!= len(pnt1) else pnt3.tolist()

#     if o==0:
cir1=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,-t)) for t in linspace(-45,45,5)] for i in arange(len(pnt1))]).tolist()
#     else:
#         cir=array([[pnt1[i]+array(q(v_rot[i],b[i]*r,t)) for t in linspace(-90,90,5)] for i in arange(len(pnt1))]).tolist()

pa=[[[[p1[i][j],p1[i][j+1],p1[i+1][j]],[p1[i+1][j+1],p1[i+1][j],p1[i][j+1]]] if j<len(p1[0])-1 else \
     [[p1[i][j],p1[i][0],p1[i+1][j]],[p1[i+1][0],p1[i+1][j],p1[i][0]]] \
     for j in range(len(p1[0]))] for i in range(len(p1)-1)]
pa=array(pa).reshape(-1,3,3)

pc=array([[[cir1[i][j],cir1[i][j+1]]  for j in arange(len(cir1[0])-1)] for i in arange(len(cir1))]).reshape(-1,2,3)

p01,p02,p03,p04,p05=pa[:,0],pa[:,1],pa[:,2],pc[:,0],pc[:,1]

v1,v2,v3=p05-p04,p02-p01,p03-p01
i,j=len(v1),len(v2)

a1=einsum('ijk,ijk->ij',array([cross(v2,v3)]*i),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t1=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(v3,-v1[:,None]),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t2=einsum('ij,ij->ij',a1,b1)

a1=einsum('ijk,ijk->ij',cross(-v1[:,None],v2),p04[:,None]-p01)
b1=(1/einsum('ijk,ijk->ij',array([-v1]*j).transpose(1,0,2),array([cross(v2,v3)+.00001]*i)))
t3=einsum('ij,ij->ij',a1,b1)

condition=(t1>=0) & (t1<=1) & (t2>=0) & (t2<=1) & (t3>=0) & (t3<=1) & (t2+t3>=0) & (t2+t3<=1)
#     condition.shape

pnt2=(p04[:,None]+einsum('ijk,ij->ijk',array([v1]*j).transpose(1,0,2),t1))[condition]
pnt2=sort_pointsv(pnt1,pnt2) if len(pnt2)!= len(pnt1) else pnt2.tolist()


sol=array([pnt3,pnt1,pnt2]).transpose(1,0,2)
sol=[fillet_3p_3d(p3,p2,p1,r_3p_3d([p1,p2,p3])*1.9,s) for (p1,p2,p3) in sol]
sol=sol+[sol[0]]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
//explanation of the process of creating fillet:

//refer plane as pl
//refer solid as sol3

//"Blue" points are the intersection points between pl and sol3
//"magenta" line at the normal drawn from the "Blue" points to pl surface
//"green" line arc is drawn with axis of rotation "navy blue" line to find the intersection point "green" with pl. radius of the arc is the radius of the fillet
//"cyan" line arc drawn with axis of rotation "navy blue" line to find the intersection point "cyan" with sol3. radius of the arc is the radius of the fillet
//with 3 points "cyan", "blue" and "green" arcs are drawn to form fillets
    
include <dependencies2.scad>
for(p={cpo(pl)})p_line3d(p,.02);
for(p={cpo(sol3)})p_line3d(p,.02);
color("blue")points({ip1},.3);
color("magenta")for(p={normals.tolist()})p_line3d(p,.05);
color("green")for(p={cir})p_line3d(p,.02);
color("green")points({pnt3},.2);
color("cyan")for(p={cir1})p_line3d(p,.03);
color("cyan")points({pnt2},.2);
color("navy")for(p={rotation_axis.tolist()})p_line3d(p,.05);
color("black")for(p={sol2})p_line3dc(p,.02);

//{swp(pl)}
//{swp(sol3)}
# %{swp(sol2)}
''')

# %%
# example of function cs(sec,d)

sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.49],[0,15,3],[30,0,3],[0,-15,2.49],[5,0,2.49],[0,20,7],[-40,0,7],[0,-20,2.49]]),20)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.05); 
color("magenta")for(p={cs(sec,-2)})p_line(p,.05);
    
    
''')

# %%
# example of function convert_secv1(sec,d)

sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.49],[0,15,3],[30,0,3],[0,-15,2.49],[5,0,2.49],[0,20,7],[-40,0,7],[0,-20,2.49]]),20)
# sec=circle(10)
# sec=pts([[0,0],[10,0],[0,10],[-10,0]])

sec1=convert_secv1(sec)


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
color("blue")p_line({sec},.1); 

color("magenta")p_line({sec1},.05);
    
''')

# %%
# example of function convert_secv(sec)

sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),40)
# sec=sec=cr(pts1([[0,0,.1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.49],[0,15,3],[30,0,3],[0,-15,2.49],[5,0,2.49],[0,20,7],[-40,0,7],[0,-20,2.49]]),20)
# sec=circle(10)
# sec=pts([[0,0],[10,0],[0,10],[-10,0]])
# path=cr(pts1([[2,0],[-2,0,2],[0,7,4.2],[-4.2,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2.2],[0,7,5.3],[-5.3,0]]),40)
# path=cr(pts1([[2,0],[-2,0,2],[0,7,2],[-2,0]]),20)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

p_line({sec},.1);
color("blue")p_line({convert_secv(sec)},.1);
    
''')

# %%
# squircle

t=linspace(0,2*pi,360)
a,b=10,5
x=sqrt(abs(cos(t)))*a*sign(cos(t))
y=sqrt(abs(sin(t)))*b*sign(sin(t))

squircle=array([x,y]).transpose(1,0).tolist()

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
p_line({squircle},.05);
    
''')

# %% [markdown]
# ![formula%20for%20superellipse.jpeg](attachment:formula%20for%20superellipse.jpeg)

# %%
sec=cr(pts1([[0,0,.1],[10,0,.1],[0,3,.1],[-3,0,.1],[0,3,.1],[-3,0,.1],[0,3,.1],[-4,0,.1]]),20)



# sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),40)
# sec=sec=cr(pts1([[0,0,1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.49],[0,15,3],[30,0,3],[0,-15,2.49],[5,0,2.49],[0,20,7],[-40,0,7],[0,-20,2.49]]),20)
# sec=circle(10)
d=-2

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
p_line({sec},.05);
color("blue")p_line({offset(sec,d)},.05);
# %offset({d})polygon({sec});
''')

# %%
# above example with the application of function io(sec, r), 'io' stands for inner offset
# this inner offset very fast but may not be very accurate

sec=cr(pts1([[0,0,.1],[10,0,.1],[0,3,.1],[-3,0,.1],[0,3,.1],[-3,0,.1],[0,3,.1],[-4,0,.1]]),20)

# sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),40)
# sec=sec=cr(pts1([[0,0,1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.49],[0,15,3],[30,0,3],[0,-15,2.49],[5,0,2.49],[0,20,7],[-40,0,7],[0,-20,2.49]]),20)
# sec=circle(10)
d=-2.5

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
p_line({sec},.05);
color("blue")p_line({io(sec,d)},.05);
# %offset({d})polygon({sec});
''')

# %%
# example of function c2ro(sol,s), 'c2ro' stands for circular to rectangular orientation

cyl=linear_extrude(circle(5,s=50),10)

cyl1=translate([15,0,0],c2ro(cyl,1))

cyl2=translate([30,0,0],cpo(c2ro(cyl,5)))

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


color("blue")for(p={cyl})p_line3dc(p,.05);
color("blue")for(p={cyl1})p_line3dc(p,.05);
color("blue")for(p={cyl2})p_line3d(p,.05);

    ''')
for i in range(23):
    with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','a')as f:
        f.write(f'''
    {swp(cyl1[i:i+1])}
    
    {swp(cyl)}
    
    ''')

# %%
# example of function c2ro(sol,s)

sp=sphere(5,s=11)

sp1=translate([15,0,0],c2ro(sp,1))

sp2=translate([30,0,0],cpo(c2ro(sp,1)))

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


color("blue")for(p={sp})p_line3dc(p,.05);
color("blue")for(p={sp1})p_line3dc(p,.05);
color("blue")for(p={sp2})p_line3d(p,.05);


    ''')

# %%
# application of function c2ro(sol, s) for creating fillet between 2 cylinders

sec=circle(5,s=50)
path=cr(pts1([[-1,2],[1,0,1],[0,10,1],[-1,0]]),10)

sol1=linear_extrude(circle(10,s=100),14)

sol2=translate([10,0,0],c2ro(prism(sec,path),10))

sol3=translate([10,0,0],prism(sec,path))

sol5=fillet_sol2sol_co(sol1,sol2,1,10,0)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
# %{swp(sol3)}
# %{swp(sol1)}
{swp(sol5)}


//color("blue")for(p={cpo(sol2)})p_line3d(p,.02);
//color("blue")for(p={sol5})p_line3dc(p,.02);
    ''')

# %%
# example of function vsp_extrude(sec,extrude_path, shape_path)

sec=circle(5)
path=bezier(pts([[5,0],[15,10],[-23,10],[0,10],[5,6],[20,-5]]),50)
path1=cr(pts1([[0,0],[0.1,35,9],[30,5]]),10)



with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
{swp(vsp_extrude(sec,path1,path))}
//color("blue")p_lineo({path},.1);
//color("magenta")p_lineo({path1},.1);
    ''')

# %%
# example of function sl_int(sec,line)

sec=cr(pts1([[0,0,1],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
sec=translate([0,0,10],q_rot(['y30','x30'],sec))
line=[[5,0,0],[8,8,10]]
ip_1=sl_int(sec,line)
    
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
color("blue")p_line3dc({sec},.1);
color("magenta")p_line3d({line},.1);
color("magenta")points({ip_1},.3);


    ''')

# %%
sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
sec=translate([0,0,10],q_rot(['y30','x30'],sec))
sol=cpo(linear_extrude(circle(2,[5,5],s=50),40))
lines=array(sol).reshape(-1,2,3)
ip_1=[sl_int(sec,line) for line in lines if sl_int(sec,line)!=[]]
ip_1=concatenate(ip_1).tolist()
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

color("blue")p_line3dc({sec},.05);
color("magenta")points({ip_1},.3);

    ''')

# %%
sec=cr(pts1([[-5,-10,1],[10,0,1],[0,15,1],[-10,0,1]]),5)
path=cr(pts1([[-5,0],[5,0,1],[0,20,1],[-5,0]]),5)
sol=prism(sec,path)
sec1=circle(2,s=100)
path1=bezier(pts2([[0,0,2],[0,5,10],[10,1,20]]),20)
sol1=path_extrude(sec1,path1)
fillet=fillet_sol2sol_co(sol,flip(sol1),.5,10,1,1.8)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>

{swp(sol)}
{swp(sol1)}
{swp(fillet)}
    ''')

# %%
# example of function end_cap(fillet,f) and axis_rot(axis, solid, angle)
sec1=circle(2,s=50)
path1=bezier(pts2([[0,0,2],[0,5,10],[10,1,20]]),20)
sol1=path_extrude(sec1,path1)
v1=array(path1[1])-array(path1[0])
plane1=translate(array(path1[0])+v1*.01,axis_rot(v1,plane(v1,20),30))
fillet1=fillet_surf2sol(plane1,sol1,1,10,0)
cap1=end_cap(fillet1)
v2=array(path1[len(path1)-1])-array(path1[len(path1)-2])
plane2=translate(array(path1[len(path1)-1])-v2*.01,axis_rot(v2,plane(v2,20),30))
fillet2=fillet_surf2sol(flip(plane2),sol1,1,10,1)
cap2=end_cap(fillet2,f=1)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
difference(){{
{swp(sol1)}
{swp_c(cap1)}
{swp_c(flip(cap2))}

}}
    ''')

# %%
# example of function axis_rot(axis,solid,angle)
vector=[2,3,5]
# sec=translate([-5,5,0],circle(5))
sec=circle(5)
sec1=[axis_rot(vector,sec,i) for i in arange(0,360,5)]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>


for(p={sec1})p_line3dc(p,.05);
//original section
color("blue")p_line3dc({sec},.05);
// axis of rotation
color("magenta")p_line3d({[[0,0,0],vector]},.1);

    ''')

# %%
sec=circle(1,s=30)
path=c2t3(circle(10,s=30))
sol1=scl3dc(path_extrude(sec,path),1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
$fn=20;
for(p={sol1})p_line3dc(p,.05);
for(p={cpo(sol1)})p_line3dc(p,.05);

    ''')

# %%
# example of function concave_hull(pnts,x)

t0=time.time()
a=random.random(1000)*(10-0)+0
b=random.random(1000)*(20-0)+0
c=array([a,b]).transpose(1,0).tolist()


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
    include<dependencies.scad>
    points({c},.2);
    color("blue")p_line3dc({concave_hull(c,2)},.1);
    
    ''')
t1=time.time()
t1-t0
# Out:
# 1.0540902614593506

# %%
# example of pies1(sec,pnts)
t0=time.time()

a=random.random(10000)*(10-0)+0
b=random.random(10000)*(20-0)+0
c=array([a,b]).transpose(1,0).tolist()


sec=cr(pts1([[1.5,8,.9],[2,0,.9],[0,-3,1.4],[3,0,1.4],[0,4,1.9],[-5,0,2.5],[0,6,2.5],
               [7,0,2.5],[0,-4,.9],[-2,0,.9],[0,3,1.4],[-3,0,1.4],[0,-4,1.9],
              [5,0,2.5],[0,-6,2.5],[-7,0,2.5]]),20)

pnts=pies1(sec,c)
pnts1=pies1(offset(sec,-.45),pnts)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
    include<dependencies.scad>
    points({c},.1);
    color("magenta")points({pnts},.1);
    color("cyan")points({pnts1},.1);
    color("blue")p_line({sec},.05);
    color("green")p_line({offset(sec,-.45)},.05);
    
    ''')

t1=time.time()
t1-t0
# Out:
# 1.9291772842407227

# %%
# another approach for very large offsets of non-convex sections

sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),15)
# sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),5)


r=10
sec1=s_int1(seg(remove_extra_points(concatenate(offset_segv(sec,r)))))
sec2=remove_extra_points(concatenate(offset_segv(sec,r)))
sec3=sec1+sec2 if sec1!=[] else sec2
sec4=cs(sec,r-.001)
sec5=[pies1(p,sec3) for p in sec4 if pies1(p,sec3)!=[]]
sec5=remove_extra_points(concatenate(sec5)) if sec5!=[] else []
sec6=exclude_points(sec3,sec5)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
    include<dependencies.scad>
    //points({sec3},.2);
    //p_line({remove_extra_points(concatenate(offset_segv(sec,r)))},.05);
    p_line({sec},.05);
    //color("blue")for(p={sec4})p_line(p,.1);
    color("magenta")points({sec6},.2);
    color("blue")p_line({concave_hull(sec6,2)},.1);
    
    ''')

# %%
# very complex rounding at the intersection

sec=circle(10)
path=cr(pts1([[2,0],[-2,0,2],[-1,15,3],[-8,0]]),10)
sol1=q_rot(['z90'],prism(sec,path))

sec1=cr(pts1([[0,0,1],[5,0,1],[0,7,2.3],[-5,0,2.3]]),10)
path1=cr(pts1([[-2.4,0],[2.4,0,2],[0,5,.3],[-.5,0]]),10)
sol2=translate([6,0,12],q_rot(['x90','z90'],prism(sec1,path1)))

sec2=circle(4,s=150)
sec3=circle(.01,s=150)
sol3=translate([6.05,1.8,0],linear_extrude(sec2,16))
sol4=translate([7,1.8,0],linear_extrude(sec3,16))


i_p1=ip_surf(sol1,sol3)
i_p2=ip_surf(sol1,sol4)

lines=cpo([i_p2,i_p1])
lines=[m_points1_o(p,32,.01) for p in lines]
lines1=translate([0,0,-1],lines)
lines2=translate([0,0,10],lines)
lines3=cpo([lines1,lines2])
i_p3=cpo([ip_surf(sol1,p) for p in lines3])

fillet1=fillet_sol2sol_co(sol2,flip(i_p3),.7,10,1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
{swp(sol1)}
{swp(sol2)}
{swp(fillet1)}

//color("blue")for(p={i_p3})p_line3dc(p,.05);
//{swp_c(i_p3)}

''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.21.38%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.21.38%20PM.png)

# %%
# example of function fillet_sol2sol_co(p=[], p1=[], r=1, s=10, o=0, f=1.8)

p1=[[0,-15,.5],[6,0,.3],[0,-16],[1,-1,.1],[4,0,.2],[0,10,4],[37,0,10],
    [0,44,10],[-37,0,4],[0,10,.2],[-4,0],[-1,-1,.1],[0,-16,.3],
    [-6,0,.5]]
sec1=cr(pts1(p1),10)

path1=c2t3(circle(10,s=100))

sec3=circle(7)
path2=cr(pts1([[2,0],[-2,25,1],[-1,0]]),10)
sol1=path_extrudec(sec1,path1)
sol3=translate([45,0,18],prism(sec3,path2))

fillet1=fillet_sol2sol(sol1,sol3,3,10)
fillet2=translate([25,0,0],fillet_sol2sol_co(sol1,sol3,3,10))
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
//original fillet
{swp_c(fillet1)}

//fillet with changes orientation
{swp(fillet2)}


''')

# %%
# example of cam profile

path1=m_points_o(cr(pts1([[0,15],[12,0,5],[10,-5,.5],[22,0]]),5),.5)
path2=array(c2t3(arc(10,0,362,s=len(path1)-1)))

path_h=array([[0,0,y] for (x,y) in path1])
path3=(path2+path_h).tolist()
sketch1=[[-1.5,0],[1.5,0]]
surf1=surf_extrude(sketch1,path3)
surf2=c2t3(c3t2(surf1))
s1,s2=array(surf1),array(surf2)

a,b=s2.transpose(1,0,2)
c,d=s1.transpose(1,0,2)
sol=array([a,c,d,b]).transpose(1,0,2).tolist()

arc1=translate([0,0,0],arc(10,10,200,s=50))
arc2=translate([0,0,50],arc1)
sol1=[arc1,arc2]

ip_1=ip_surf(sol,sol1)
ip_1=min_d_points(ip_1,.1)

sec=circle(.75)
sol2=path_extrude(sec,ip_1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
//points({path1},.2);
//points({path3},.2);
//color("magenta")p_line3d({ip_1},.2);
difference(){{
{swp(sol)}
{swp(sol2)}
}}
''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.20.08%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.20.08%20PM.png)

# %%
# 2w wheel completely designed in openscad, it takes 135 sec to compute

t1=time.time()

p0=[[-3,-5-41/2,3],[15,-5,2],[0,7,5],[-12,3,2],[-1,8,.5],[1,1,2],
    [-.25,2,2],[-8,2,3],[0,15,3],[8,2,2],[0.25,2,2],
   [-1,1,1],[1,8,2],[12,3,5],[0,7,2],[-15,-5,3],[-2,-13,2],
   [-8,-2,3],[-2,-10.5,3],[2,-10.5,3],[8,-2,3]]
sec=cr(pts1(p0),10)
path=c2t3(circle(12*25.4/2,s=200))
sol=path_extrudec(sec,path)

p1=[[0,-15,.5],[6,0,.3],[0,-16,.1],[1,-1,.1],[4,0,.2],[2,10,4],[35,0,10],
    [5,22,5],[-5,22,10],[-35,0,4],[-2,10,.2],[-4,0,.1],[-1,-1,.1],[0,-16,.3],
    [-6,0,.5]]
sec1=cr(pts1(p1),10)
sec2=offset(sec1,-4)
path1=c2t3(circle(10,s=100))
sol1=path_extrudec(sec1,path1)
sol2=path_extrudec(sec2,path1)
sec3=circle(7)
path2=cr(pts1([[2,0],[-2,25,.1],[-3,0,.1],[0,-14,.1],[-3.9,-3.9]]),10)

sol3=translate([45,0,18],prism(sec3,path2))

fillet1=fillet_sol2sol(sol1,sol3,3,10)

arc1=flip(c2t3(arc(30,13,60,s=10)))
arc2=c2t3(arc(45,18,55,s=10))

p2=(array(arc2[0])+[0,0,3]).tolist()
p3=arc2[1:-1]
p4=(array(arc2[-1])+[0,0,3]).tolist()
p5=(array(arc1[0])+[0,0,3]).tolist()
p6=arc1[1:-1]
p7=(array(arc1[-1])+[0,0,3]).tolist()

pl=[p2]+p3+[p4]+[p5]+p6+[p7]
sec4=cr(pl,10)
sol4=linear_extrude(sec4,50)


sol5=q_rot(['z45'],translate([45,0,-18],q_rot(['y180'],prism(sec3,path2))))
fillet2=fillet_sol2sol(sol1,sol5,2,10)

sol6=q_rot(['z-35'],translate([0,0,-50],sol4))

sec5=cr(pts1([[-20,-7.5,2],[5,0,2],[0,10,3],[15,2,70],[15,-2,3],[0,-10,2],
             [5,0,2],[0,15,7],[-20,3,90],[-20,-3,7]]),10)

sec5=m_points(sec5,1)

sol7=q_rot(['z10'],translate([0,53,0],q_rot(['x90','z180'],linear_extrude(sec5,10))))
ip_1=ip_surf(sol1,sol7)


sol8=q_rot(['z20'],translate([0,130,0],q_rot(['x90','z180'],linear_extrude(scl2d_c(sec5,.7),10))))
ip_2=ip_surf(sol,sol8)

sol9=[translate([0,-.1,0],ip_1),translate([0,.1,0],ip_2)]

fillet3=fillet_sol2sol(sol1,sol9,2.5,10,0,1.9)
fillet3=cpo(fillet3)[1:]
fillet4=fillet_sol2sol(sol,sol9,2,10,1,1.9)
fillet4=cpo(fillet4)[1:]




with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies2.scad>
//render(){{
rotate_extrude($fn=200)translate([12*25.4/2,0,0])polygon({sec});

difference(){{
rotate_extrude($fn=200)translate([10,0,0])polygon({sec1});
rotate_extrude($fn=200)translate([10,0,0])polygon({sec2});
for(i=[0:360/5:359])rotate([0,0,i])
linear_extrude(50)polygon({sec4});

for(i=[0:360/4:359])rotate([0,0,i])
translate([0,0,-50])rotate([0,0,-35])linear_extrude(50)polygon({sec4});

}}

for(i=[0:360/5:359])
rotate([0,0,i]){{
{swp(sol3)}
{swp_c(fillet1)}
}}

for(i=[0:360/4:359])
rotate([0,0,i]){{
{swp(sol5)}
{swp_c(fillet2)}
}}

for(i=[0:360/5:359])
rotate([0,0,i]){{
{swp(sol9)}
{swp(flip(fillet3))}
{swp(fillet4)}
}}


//}}

    ''')
    
t2=time.time()
t2-t1
# Out:
# 137.27440905570984

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.18.54%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.18.54%20PM.png)

# %%
# drill bit

sec=circle(7.5,s=101)
path=pts([[-7.5*cos(360/200*pi/180),0],[7.5,5],[0,70]])
sol=prism(sec,path)
hx1=helix(7.5,20,2,5)
hx2=q_rot(['z180'],hx1)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
    include<dependencies2.scad>
//    render(){{
difference(){{
   color("orange"){swp(sol)}
   color("cyan")p_line3d({hx1},2.5,$fn=70);
   color("cyan")p_line3d({hx2},2.5,$fn=70);
   
   }}
//   }}
    ''')

# %%
# bottle with cut design

t0=time.time()
sec=circle(10,s=70)
path=cr(pts1([[-3,0,0],[3,0,3],[3,5,7],[-5,20,100],[8,30,20],[-11,10,5],[0,10,0]]),20)
path1=path+flip(path_offset(path,-.9))
sec1=cr(pts1([[-5,0,3],[10,0,3],[0,20,30],[-3,20,30],[0,10,2],[-4,0,2],[0,-10,30],[-3,-20,30]]),20)

sol1=q_rot(['z0'],prism(sec,path))
sol2=translate([0,0,5],q_rot(['x90','z90'],linear_extrude(m_points(sec1,1.11),30)))
sol3=cpo(fillet_sol2sol(flip(sol1),sol2,.5,10,1))[1:]
sol3=sol3+[translate([2,0,0],sol3[len(sol3)-1])]
sol4=flip(translate([-1,0,0],cpo(fillet_sol2sol(sol1,sol2,.5,10,1))[1:]))
sol5=[translate([-2,0,0],sol4[0])]+sol4+sol3
sol6=prism(sec,path1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies.scad>
render(){{
difference(){{
{swp(sol1)}
for(i=[0:360/4:359])
rotate([0,0,i])
translate([0.03,0,0])
intersection()
{{
{swp(sol5)}
{swp(sol6)}
}}
}}
}}

    ''')
t1=time.time()
t1-t0
# Out:
# 11.581695079803467

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.15.00%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.15.00%20PM.png)

# %%
# m10
t0=time.time()

sec1=arc(20,0,359,s=150)
path1=[[0,0],[-5,25]]

surf1=prism(sec1,path1)

sec2=cr(pts1([[-25,0],[10,5,5],[10,-3,10],[10,5,5],[10,-8,7],[10,1]]),10)  
path2=cytz(cr(pts1([[-35,5,0],[10,8,20],[20,-5,10],[20,8,20],[10,-9,20],[10,1,0]]),10))
surf2=surf_extrude(sec2,path2)

p=fillet_surf2sol(surf2,surf1,2,10,0)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies.scad> 
{swp(surf1)}
{swp(surf_extrudef(surf2,-.05))}
{swp_c(p)}


''') 
t1=time.time()
total=t1-t0
total
# Out:
# 2.0530388355255127

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.13.22%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.13.22%20PM.png)

# %%
# hollow sphere with pocket

sp1=q_rot(["z90"],sphere(10))
sp2=q_rot(["z90"],sphere(9))
cyl=q_rot(["y30"],linear_extrude(arc(3,0,355,s=50),30))
fillet1=fillet_sol2sol_co(sp2,cyl,.7,10,0)
fillet2=fillet_sol2sol_co(flip(sp1),cyl,.7,10,1)
a=translate(nv(fillet1[len(fillet1)-1]),fillet1[len(fillet1)-1])
sol1=flip(fillet1+[a])

b=translate(array(nv(fillet2[len(fillet2)-1]))*-1,fillet2[len(fillet2)-1])
sol2=fillet2+[b]


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f''' 
    include<dependencies2.scad>
   difference(){{
   {swp(sp1)}
   {swp(sp2)}
   {swp(cyl)}
   {swp(sol1)}
   //color("blue")p_line3dc({fillet1[len(fillet1)-1]},.1);
   //color("blue")p_line3dc({a},.1);
   
   {swp(sol2)}
   //color("blue")p_line3dc({fillet2[len(fillet2)-1]},.1);
   //color("blue")p_line3dc({b},.1);
   
   }}
    
    
    
    ''')
    
nv(fillet1[0])
# Out:
# [-0.3615981027911127, 0.014686927309556152, -0.9322183790422026]

# %%
# m37 rounded

sec=[[i,3*sin(i*18*pi/180)] for i in arange(-20,20,.5)]

path=[[i,0,20+3*sin(i*12*pi/180)] for i in arange(-30,30,.5)]

surf=surf_extrude(sec,path)

sec1=cr(pts1([[0,0,2],[20,0,2],[0,20,2]]),40)

sol1=translate([0,0,-.5],q_rot(["z.001"],linear_extrude(m_points(sec1,.5),40)))
sol01=translate([0,0,-.5],q_rot(["z.001"],linear_extrude(m_points(offset(sec1,.5),.5),40)))



sol2=cpo(ipf(surf,flip(sol1),1,10,0))[1:]
ip=sort_pointsv(sol2[0],ip_surf(surf,sol01))
sol2=[translate([0,0,10],ip)]+[ip]+sol2+[translate([0,0,10],sol2[len(sol2)-1])]+[translate([0,0,10],ip)]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
    render(){{
    difference(){{
    intersection(){{
    {swp(surf_base(surf,0))}
    {swp(sol1)}
   }}
   {swp_c(sol2)}
    }}
    }}
    ''')

# %%
# m39

l1=tcct(10,30,[-35,0],[0,-34])
l2=tcct(10,30,[35,0],[0,-34],1)
l3=cir_p_t(circle(10,[35,0],s=50),[45,35])
l4=p_cir_t([45,35],circle(10,[0,45],s=100))
l5=cir_p_t(circle(10,[0,45],s=100),[-45,35])
l6=p_cir_t([-45,35],circle(10,[-35,0],100))

arc1=c2t3(arc_2p(l1[1],l2[1],30,1,20))
arc2=c2t3(arc_2p(l2[0],l3,10,-1,20))
pnt1=[[45,35,10]]
arc3=c2t3(arc_2p(l4,l5,10,-1,20))
pnt2=[[-45,35,10]]
arc4=c2t3(arc_2p(l6,l1[0],10,-1,20))
sec=cr(arc1+arc2+pnt1+arc3+pnt2+arc4,20)
path1=cr(pts1([[-1.25,0],[1.25,0,1.25],[0,10,1.25],[-1.25,0]]),10)

l01=tcct(7.5,32.5,[-35,0],[0,-34])
l02=tcct(7.5,32.5,[35,0],[0,-34],1)
l03=cir_p_t(circle(7.5,[35,0],s=50),[45-2.5,35-1.25])
l04=p_cir_t([45-2.5,35-1.25],circle(7.5,[0,45],s=100))
l05=cir_p_t(circle(7.5,[0,45],s=100),[-45+2.5,35-1.25])
l06=p_cir_t([-45+2.5,35-1.25],circle(7.5,[-35,0],100))

arc01=c2t3(arc_2p(l01[1],l02[1],32.5,1,20))
arc02=c2t3(arc_long_2p(l02[0],l03,7.5,1,50))
pt01=[[arc02[0][0],arc02[0][1],2.5]]
ar02=arc02[8:-8]
pt02=[[arc02[len(arc02)-1][0],arc02[len(arc02)-1][1],2.5]]
pnt01=[[45-2.5,35-1.25,7.5]]
arc03=c2t3(arc_long_2p(l04,l05,7.5,1,50))
pt03=[[arc03[0][0],arc03[0][1],2.5]]
ar03=arc03[8:-8]
pt04=[[arc03[len(arc03)-1][0],arc03[len(arc03)-1][1],2.5]]
pnt02=[[-45+2.5,35-1.25,10]]
arc04=c2t3(arc_long_2p(l06,l01[0],7.5,1,50))
pt05=[[arc04[0][0],arc04[0][1],2.5]]
ar04=arc04[8:-8]
pt06=[[arc04[len(arc04)-1][0],arc04[len(arc04)-1][1],2.5]]
sec0=cr(arc01+pt01+ar02+pt02+pnt01+pt03+ar03+pt04+pnt02+pt05+ar04+pt06,20)
path2=cr(pts1([[-1.25,1.25],[1.25,0,1.25],[0,10-1.25,1.25],[1.25,0],[0,.2]]),10)

sec1=circle(5,s=50)
path3=cr(pts1([[0.5,-.2],[0,0.2],[-.5,.5],[0,9],[.5,.5],[0,.2]]),5)
sol=prism(sec1,path3)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
    include<dependencies.scad>
    //render(){{
    difference(){{
    difference(){{
    {swp(prism(sec,path1))}
    {swp(prism(sec0,path2))}
    }}
    {swp(translate([-35,0,0],sol))}
    {swp(translate([35,0,0],sol))}
    {swp(translate([0,45,0],sol))}
    }}
   // }}
    
    
    ''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.11.54%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.11.54%20PM.png)

# %%
# rounded star

t=1.1 # thickness
s=10 # number of sides of the star
d=20 # outer diameter of the star
h=50 # height of the star prism
cir1=circle(d,s=(s+1))
cir2=c3t2(q_rot([f"z{360/(s+1)/2}"],circle(d/4,s=(s+1))))
sec1=array(c2t3([cir1,cir2]))
sec1=sec1.transpose(1,0,2).reshape(-1,3)
sec1=sec1
sec1=[(sec1[i]+[0,0,1]).tolist() if i%2==0 else (sec1[i]+[0,0,t]).tolist() for i in range(len(sec1)) ]
sec1=m_points(cr(sec1,20),1.1)
sec2=m_points(offset(cr(sec1,20),.2),1.1)
sol1=linear_extrude(sec1,h)

line1=cr(pts1([[-20,0],[20,30,50],[20,-30]]),40)
line2=cytz(line1)
surf1=surf_extrude(line1,line2)
surf2=translate([0,0,-t],surf1)

sol2=cpo(fillet_surf2sol(flip(surf1),sol1,.5,10,0))[1:]
ip1=sort_pointsv(sol2[0],ip_surf(surf1,linear_extrude(sec2,h)))



sol2=[translate([0,0,10],ip1)]+[ip1]+sol2+[translate([0,0,10],sol2[len(sol2)-1])]+[translate([0,0,10],ip1)]

sol3=cpo(fillet_surf2sol(surf2,sol1,.5,10,1))[1:]
ip2=sort_pointsv(sol3[0],ip_surf(surf2,linear_extrude(sec2,h)))
sol3=[translate([0,0,-5],ip2)]+[ip2]+sol3+[translate([0,0,-5],sol3[len(sol3)-1])]+[translate([0,0,-5],ip2)]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies.scad> 

render(){{
difference(){{
intersection(){{
{swp(surf_extrudef(surf1,-t))}
{swp(sol1)}
}}
{swp_c(sol2)}
{swp_c(sol3)}
}}

}}


''')
# Out:
# /Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/python/openscad1.py:153: RuntimeWarning: invalid value encountered in arccos
#   theta0= (180-arccos(einsum('ij,ij->i',u0,u1))*180/pi)/2
# /Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/python/openscad1.py:154: RuntimeWarning: invalid value encountered in arccos
#   theta1= (180-arccos(einsum('ij,ij->i',u2,u3))*180/pi)/2
# /Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/python/openscad1.py:155: RuntimeWarning: invalid value encountered in arccos
#   theta2= (180-arccos(einsum('ij,ij->i',u4,u5))*180/pi)/2

# %%
# 4w wheel in openscad

initial_time=time.time()
path7=cr(pts1([[0,0],[0,5],[-13,20],[0,20],[-12,20],[0,78],[12,20],[0,64],[13,20],[0,5]]),5)
sec7=circle(245,s=72)

sec10=cr(pts1([[-100,0],[100,30,500],[100,-30]]),20)
path10=translate([0,0,190],q_rot(["y-5","z-15"],cytz(cr(pts1([[0,0],[130,30,1000],[260,-10,0]]),20))))

sec1=cr([[300,0,7], [0,0,10] , [300*cos(-30*pi/180),300*sin(-30*pi/180),7]]+c2t3(arc(300,-30,0,[0,0],s=10)[1:-1]),10)
sol1=linear_extrude(sec1,300)
surf1=surf_extrude(sec10,path10)
sec2=cr([[300,0,1], [0,0,15] , [300*cos(-30*pi/180),300*sin(-30*pi/180),1]]+c2t3(arc(300,-30,0,[0,0],s=10))[1:-1],20)
sol2=translate([50*cos(-15*pi/180),50*sin(-15*pi/180),0],linear_extrude(sec2,300))
sec3=cr([[300,0,1], [0,0,15] , [300*cos(-30*pi/180),300*sin(-30*pi/180),1]]+c2t3(arc(300,-30,0,[0,0],s=10))[1:-1],20)
sol3=translate([50*cos(-15*pi/180),50*sin(-15*pi/180),0],linear_extrude(m_points(sec3,10),300))
ip1=ip_surf(surf1,sol3)
sec4=cr(pts1([[3,0,0],[0,3,1.5],[-3,0,1.5],[0,-3,0]]),10)
bead1=path_extrude(sec4,ip1)


sec=cr(pts1([[-100,0],[100,30,500],[100,-30]]),20)
path=translate([0,0,217],q_rot(["y10","z15"],cytz(cr(pts1([[0,0],[130,30,1000],[260,-10,0]]),20))))

surf=surf_extrude(sec,path)
sec5=cr([[300*cos(30*pi/180),300*sin(30*pi/180),7],[0,0,10],[300,0,7]]+c2t3(arc(300,0,30,[0,0],s=10))[1:-1],10)
sol4=linear_extrude(sec5,300)
sec6=cr([[300*cos(30*pi/180),300*sin(30*pi/180),10],[0,0,30],[300,0,10]]+c2t3(arc(300,0,30,[0,0],s=10))[1:-1],40)
sol5=translate([50*cos(15*pi/180),50*sin(15*pi/180),0],linear_extrude(m_points(sec6,10),300))
ip2=ip_surf(surf,sol5)
ip2= remove_extra_points(array(ip2).round(4))
bead2=path_extrudec(sec4,ip2)
cyl1=cylinder(r=15,h=300,cp=[110*cos(15*pi/180),110*sin(15*pi/180)],s=40)
ip3=ip_surf(surf,cyl1)
ip3=remove_extra_points(array(ip3).round(4))
bead3=path_extrudec(sec4,ip3)


sec8=cr(pts1([[0,0],[2.5,0,2.5],[0,45,2.5],[-5,0,2.5],[0,-45,2.5]]),20)
sol6=translate([22,0,205],q_rot(["x90","z90"],linear_extrude(m_points(sec8,.25),300)))

sec9=circle(245,s=100)
path9=cr(pts1([[2,0],[-2,0,2],[0,5,5],[-13,20,5],[0,20,5],[-12,20,5],[0,78,5],[12,20,5],[0,64,5],[13,20,5],[0,5,2],[2,0]]),5)
sol7=prism(sec9,path9)


sol8=fillet_sol2sol(flip(sol7),sol6,1.5,10,1)


sec11=circle(45,s=100)
path11=cr(pts1([[0,200],[5,0,5],[0,40,5],[-25,15,5],[-24.5,0]]),15)
sol9=prism(sec11,path11)
sol10=fillet_sol2sol(sol9,sol6,1.5,10,0)

sec12=cr([[50,0,4],[0,0,15],[50*cos(-30*pi/180),50*sin(-30*pi/180),4]]+c2t3(arc(50,-30,0,[0,0],10))[1:-1],15)
sol12=linear_extrude(sec12,300)
sol13=fillet_surf2sol(surf1,sol12,2,10,0)
sol14=q_rot(["z30"],sol12)
sol15=fillet_surf2sol(surf,sol14,2,10,0)
sol16=linear_extrude(m_points(offset(sec1,-2.5),10),300)
sol17=fillet_surf2sol(surf1,sol16,2,10,1)
sol18=q_rot(["z30"],sol16)
sol19=fillet_surf2sol(surf,sol18,2,10,1)
sol20=q_rot(["z30"],sol6)
sol21=q_rot(["z30"],sol8)
sol22=q_rot(["z30"],sol10)

sec13=circle(250,s=100)
path12=cr(pts1([[-2,0],[2,0,2],[0,5,5],[-13,20,5],[0,20,5],[-12,20,5],[0,78,5],[12,20,5],[0,64,5],[13,20,5],[0,5,2],[-2,0]]),5)

sol23=prism(sec13,path12)


surf2=translate([0,0,-5],surf1)
sol24=fillet_surf2sol(surf2,sol2,1.5,10,0)
sol25=fillet_surf2sol(flip(surf2),sol16,2,10,0)
sol26=fillet_surf2sol(flip(surf2),sol12,2,10,1)

surf3=translate([0,0,-5],surf)
sol27=fillet_surf2sol(flip(surf3),sol18,2,10,0)
sol28=fillet_surf2sol(flip(surf3),sol14,2,10,1)

cyl2=cylinder(r=10,h=300,cp=[110*cos(15*pi/180),110*sin(15*pi/180)],s=50)
sol29=[ip_surf(surf3,cyl2)+[ip_surf(surf3,cyl2)[0]]]+ipe(surf3,cyl1,2,10,0)
sol05=translate([50*cos(15*pi/180),50*sin(15*pi/180),0],linear_extrude(m_points(offset(sec6,-5),10),300))

sol30=[ip_surf(surf3,sol05)+[ip_surf(surf3,sol05)[0]]]+ipe(surf3,sol5,2,10,0)
sol31=ipe(surf2,sol3,2,10,0)


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
    
//    render(){{
    
    // spoke 1
    
    for(i=[0:60:300])rotate([0,0,i])
    difference(){{
    difference(){{
    intersection(){{
    {swp(surf_extrudef(surf_extrude(sec,path),-5))}
    {swp(sol4)}
    {swp(sol7)}
    }}
    {swp(sol5)}
    {swp(cyl1)}
    
    }}
    {swp(flip(ipe(surf3,cyl1,2,10,0)))}
    {swp(flip(ipe(surf3,sol5,2,10,0)))}
    
    }}
    
        for(i=[0:60:360-60])
        rotate([0,0,i])
    intersection(){{
        color("blue"){swp_c(flip(sol19))}
        {swp(sol7)}
      }}
     
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol15)}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp_c(sol27)}
    {swp(sol7)}
      }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol28)}
      
    for(i=[0:60:300])rotate([0,0,i])
    intersection(){{
    {swp_c(bead2)}
    {swp(sol7)}
        }}
        
    for(i=[0:60:300])rotate([0,0,i]){{
    {swp_c(bead3)}
    }}
    
    // spoke 2
    
    
    {{for(i=[0:60:300])rotate([0,0,i])
    difference(){{
    intersection(){{
    {swp(surf_extrudef(surf_extrude(sec10,path10),-5))}
    {swp(sol1)}
    {swp(sol7)}
    }}
    {swp(sol2)}
    {swp(flip(sol31))}
    }}
    }}
    
    

    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp(bead1)}
    {swp(sol7)}
    }}

    for(i=[0:60:360-60])
    rotate([0,0,i]){{
    intersection(){{
    {swp_c(sol25)}
    {swp(sol7)}
    }}
    {swp_c(sol26)}
    }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol13)}

    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp_c(flip(sol17))}
    {swp(sol7)}
    }}
    
    // spoke 3
    for(i=[0:30:360-30])
    rotate([0,0,i])
    intersection(){{
    {swp(sol6)}
    {swp(sol7)}
    }}
    
    for(i=[0:30:360-30])
    rotate([0,0,i]){{
    {swp_c(sol8)}
    {swp_c(sol10)}
    }}
    
    // hub
    difference(){{
    {swp(sol9)}
    {swp(cylinder(r=20,h=300,s=72))}
    
    }}
    
    // rim
    {swp_c(swp_prism_h(sol23,sol7))}    
    
    
//    }}
    
    ''')   
    
final_time=time.time()
final_time-initial_time
# Out:
# 22.132517337799072

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.10.11%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.10.11%20PM.png)

# %%
# cylinder with rectangular pocket
t=2 #thickness
n=100 # number of segments in the circle
s=[25,25] #size of the pocket
cir=circle(20,s=n)
path=cr(pts1([[t/2,0,t/2],[0,80,t/2],[-t,0,t/2],[0,-80,t/2]]),20)
sol1=prism(cir,path)
sol1=sol1+[sol1[0]]

sec1=cr(pts1([[-s[1]/2,-s[0]/2,t],[s[1],0,t],[0,s[0],t],[-s[1],0,t]]),10)
sol2=translate([0,0,40],q_rot(["y90"],linear_extrude(m_points(sec1,.51),40)))

cyl1=q_rot(["z90"],cylinder(r=20+t/2,h=80,s=n))
cyl2=q_rot(["z90"],cylinder(r=20-t/2,h=80,s=n))


sol3=cpo(fillet_sol2sol(flip(cyl1),sol2,t/2,10,1))[1:]
sol3=[translate([-1,0,0],sol3[0])]+sol3+[translate([1,0,0],sol3[len(sol3)-1])]

sol4=cpo(fillet_sol2sol(cyl2,sol2,t/2,10,0))[1:]
sol4=[translate([1,0,0],sol4[0])]+sol4+[translate([-1,0,0],sol4[len(sol4)-1])]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
render(){{
difference(){{
{swp_c(sol1)}
{swp(sol2)}
{swp(sol4)}
{swp(sol3)}
}}
}}

''')

# %%
# cylinder with star pocket

t=2 # thickness
n=100 # number of segments of circle
s=6 # number of sides of the star
d=21 # outer diameter of the star
h=50 # height of the star prism
cir1=circle(d,s=(s+1))
cir2=c3t2(q_rot([f"z{360/(s+1)/2}"],circle(d/4,s=(s+1))))
sec1=array(c2t3([cir1,cir2]))
sec1=sec1.transpose(1,0,2).reshape(-1,3)
sec1=sec1
sec1=[(sec1[i]+[0,0,t/1.5]).tolist() if i%2==0 else (sec1[i]+[0,0,t]).tolist() for i in range(len(sec1)) ]
sec1=cr(sec1,20)
sol1=translate([0,0,40],q_rot(["y90"],linear_extrude(m_points(sec1,1.1),h)))

cir=circle(20,s=n)
path=cr(pts1([[t/2,0,t/2],[0,80,t/2],[-t,0,t/2],[0,-80,t/2]]),10)
sol2=prism(cir,path)
sol2=sol2+[sol2[0]]

cyl1=q_rot(["z90"],cylinder(r=20+t/2,h=80,s=n))
cyl2=q_rot(["z90"],cylinder(r=20-t/2,h=80,s=n))


sol3=cpo(fillet_sol2sol(flip(cyl1),sol1,t/2,10,1))[1:]
sol3=[translate([-3,0,0],sol3[0])]+sol3+[translate([3,0,0],sol3[len(sol3)-1])]

sol4=cpo(fillet_sol2sol(cyl2,sol1,t/2,10,0))[1:]
sol4=[translate([3,0,0],sol4[0])]+sol4+[translate([-3,0,0],sol4[len(sol4)-1])]


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
render(){{

difference(){{
{swp_c(sol2)}
{swp(sol1)}
{swp(sol3)}
{swp(sol4)}
}}


}}

''')

# %%
# lamp

n=20 #number of strands in the lamp
t=5 # thickness of each strand
path=[[42,0],[62,50],[25,100],[25,180]]

path1=cytz(bezier(path,100))

path2=[q([0,0,1],path1[i],i/(len(path1)-1)*(180+1.8)) for i in range(len(path1)-1)]

sol=[]
for i in range(len(path2)):
    theta=ang(path2[i][0],path2[i][1]) 
    sol.append(translate(path2[i],q_rot([f'z{theta}'], \
            offset(square(t,center=True),i/len(path2)*-1.5))))
sol=q_rot(['z0'],sol)

c1=circle(45)
c2=circle(30)


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
for(i=[0:360/{n}:359])
rotate([0,0,i])
{{
{swp(sol)}
//p_line3d({path2},.5);
mirror([0,1,0])
{swp(sol)}
//p_line3d({path2},.5);

}}
linear_extrude(2)
difference()
{{
polygon({c1});
polygon({c2});

}}
''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.07.35%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.07.35%20PM.png)

# %%
# samsung tab s6 holder to hang in car back seat

sec=cr(pts1([[0,0,.1],[124,0,3],[27*cos(45*pi/180),27*sin(45*pi/180),1],
             [15*cos(135*pi/180),15*sin(135*pi/180),1],
             [5*cos((180+45)*pi/180),5*sin((180+45)*pi/180),1],
             [10*cos(-45*pi/180),10*sin(-45*pi/180),1],
             [17*cos((180+45)*pi/180),17*sin((180+45)*pi/180),1],
             [10*cos(135*pi/180),10*sin(135*pi/180),1],
             [8*cos(225*pi/180),8*sin(225*pi/180),1],[20*cos(135*pi/180),20*sin(135*pi/180),1],
             [8*cos(45*pi/180),8*sin(45*pi/180),1],
             [105*cos(135*pi/180),105*sin(135*pi/180),1],
             [8*cos(225*pi/180),8*sin(225*pi/180),1],
             [20*cos(135*pi/180),20*sin(135*pi/180),1],
             [8*cos(45*pi/180),8*sin(45*pi/180),1],[10*cos(135*pi/180),10*sin(135*pi/180),1],
             [17*cos(45*pi/180),17*sin(45*pi/180),1],[10*cos(-45*pi/180),10*sin(-45*pi/180),1],
             [5*cos(45*pi/180),5*sin(45*pi/180),1],[15*cos(135*pi/180),15*sin(135*pi/180),1],
             [17*cos(225*pi/180),17*sin(225*pi/180),1],[0,30,2],[-7,0,1]]),10)


sec1=cr(pts1([[0,0,2],[17,0,2],[0,85,2],[-17,17,2]]),5)
path1=[[0,0],[0,6]]
sol=translate([123.5,7.7,30],q_rot(["x90","z45"],prism(sec1,path1)))


sol1=translate([5,129,130],q_rot(["x90","z45"],prism(sec1,path1)))

sec2=cr(pts1([[0,0,4],[10,0,4],[0,40,4],[-10,0,4]]),5)
path2=[[0,0],[0,8]]
sol2=translate([-0.25,140,40],q_rot(["x90","z90"],prism(sec2,path2)))

sol3=translate([-0.25,140,170],q_rot(["x90","z90"],prism(sec2,path2)))

sec4=cr(pts1([[0,0,0],[15,0,5],[0,90,5],[-15,0,0]]),5)
path4=[[0,0],[0,3]]
sol4=translate([90,35,0],q_rot(["z45"],prism(sec4,path4)))

sec5=cr(pts1([[0,0],[120,0,0],[32*cos(135*pi/180),32*sin(135*pi/180),1],
              [8*cos(45*pi/180),8*sin(45*pi/180),1],
              [105*cos(135*pi/180),105*sin(135*pi/180),1],[8*cos(225*pi/180),8*sin(225*pi/180),1],
              [33*cos(135*pi/180),33*sin(135*pi/180),0]]),5)

sec6=cr(pts1([[0,0,5],[90,0,5],[0,110,5],[-90,90,5]]),5)
path6=[[0,0],[0,7]]

sol6=translate([15,6,25],q_rot(["x90"],prism(sec6,path6)));
sol7=translate([-1,15,25],q_rot(["x90","z90"],prism(sec6,path6)));
sol8=translate([95,30,25],q_rot(["x90","z135"],prism(sec6,path6)));

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
rotate([90,0,0])
{{
difference(){{
linear_extrude(250)
difference(){{
polygon({sec});
polygon({offset(sec,-4)});
}}
color("blue"){swp(sol)}
color("blue"){swp(sol1)}
color("blue"){swp(sol2)}
color("blue"){swp(sol3)}
color("blue"){swp(sol6)}
color("blue"){swp(sol7)}
color("blue"){swp(sol8)}
}}

color("magenta"){swp(sol4)}
}}
''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.06.11%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.06.11%20PM.png)

# %%
# business card holder

sec=cr(pts1([[0,0,1],[95,0,1],[0,10,1],[-95,0,1]]),10)

sol2=linear_extrude(offset(sec,1),1);

sec1=cr(pts1([[10,0,5],[50,0,5],[10,30],[-70,0]]),10);

sol3=translate([12.5,2,21],q_rot(["x90"],linear_extrude(sec1,5)));

# difference(){
# union(){
# sol4=swp_prism_h(prism1,prism)
# swp(prism2);}
# swp(prism3);}


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
render(){{
difference(){{
linear_extrude(50)
difference(){{
polygon({offset(sec,1)});
polygon({sec});
}}

{swp(sol3)}
}}
{swp(sol2)}
}}
''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.04.34%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.04.34%20PM.png)

# %%
# m38

cir1=circle(3,[14.5,0])
cir2=circle(3,[-14.5,0])
cir3=circle(6.5)

p0=tctpf(r1=17.5,r2=7.5,cp1=[0,0],cp2=[14.5,0])
p1=tctpf(r1=17.5,r2=7.5,cp1=[0,0],cp2=[-14.5,0])

arc1=arc_2p(p0[2],p0[1],7.5,-1,10)
arc2=arc_2p(p0[0],p1[3],17.5,-1,20)
arc3=arc_2p(p1[2],p1[1],7.5,-1,10)
arc4=arc_2p(p1[0],p0[3],17.5,-1,20)
sec1=arc1+arc2+arc3+arc4

sol1=linear_extrude(sec1,5.5)

sec2=circle(10)
sec3=circle(6.5)
path1=c2t3(cr(pts1([[0,0],[0,29,17.5],[-44,0]]),20))
sol2=q_rot(['x90'],path_extrude(sec2,path1))
sol3=q_rot(['x90'],path_extrude(sec3,path1))
sol4=swp_prism_h(sol2,sol3)

cir4=circle(39/2)
cir5=circle(2,[15,0])

sol5=translate([-40,0,29],q_rot(['y-90'],linear_extrude(cir4,4)))

fillet1=fillet_surf2sol(flip(translate([0,0,5.5],plane([0,0,1],20))),sol2,1.25,10,1)
fillet2=fillet_surf2sol(flip(translate([-40,0,29],plane([-1,0,0],20))),sol2,1.25,10,0)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

//p_line({p0},.05);
//for(i=[0:len({p0})-1])translate({p0}[i])text(str(i),1);

//p_line({p1},.05);
//for(i=[0:len({p1})-1])translate({p1}[i])text(str(i),1);

linear_extrude(5.5)
difference(){{
polygon({sec1});
polygon({cir1});
polygon({cir2});
polygon({cir3});
}}

{swp_c(sol4)}

translate([-40,0,29])
rotate([0,-90,0])
linear_extrude(4)
difference(){{
polygon({cir4});
for(i=[0,90,180,270])
rotate([0,0,i])
polygon({cir5});
polygon({cir3});
}}

{swp_c(fillet1)}
{swp_c(fillet2)}

''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%2010.01.54%20PM.png](attachment:Screenshot%202023-01-15%20at%2010.01.54%20PM.png)

# %%
# m35

p0=[15,0]
p1=[15,45]
cir1=circle(7.5,[0,75-7.5])
p2=p_cir_t(p1,cir1)
p4=[-15,45]
p3=cir_p_t(cir1,p4)
arc1=arc_2p(p2,p3,7.5,-1,45)
p5=[-15,0]
p0,p1,arc1,p4,p5=[[15,0,0]],[[15,45,1]],c2t3(arc1),[[-15,45,1]],[[-15,0,0]]
sec=cr(p0+p1+arc1+p4+p5,10)
sec=m_points(sec,.5)

l1=c3t2(translate([-.0005,5,0],m_points(square([.001,50]),.2)))
sec1=cpo([sort_points(sec,l1),sec])
sec1=cpo([ls(p,20) for p in sec1])+[sec]

path=cr(pts1([[0,0],[45,0,1],[40*cos(d2r(30)),40*sin(d2r(30))]]),10)
path=q_rot(['x90','z90'],path)

surf1=flip([wrap_around(p,path) for p in sec1])
surf2=surf_offset(surf1,-4)
sol=translate([0,0,9+4],q_rot(['z-90'],flip(surf1)+surf2+[flip(surf1)[0]]))

sec2=[circle(.5,[0,75-7.5]),circle(3.75,[0,75-7.5])]
surf3=flip([wrap_around(p,translate([0,0,.001],path)) for p in sec2])
surf4=surf_offset(surf3,-4.1)
sol1=translate([0,0,9+4],q_rot(['z-90'],flip(surf3)+surf4))

path=cytz(pts([[0,9],[25.5+19.5,0],[(30-7.5)*cos(45*pi/180),(30-7.5)*sin(45*pi/180)]]))
# sec1=c2t3(m_points_o(pts([[-15,0],[30,0],[0,5],[-30,0]]),1))

sec3=[[-30,-15]]+arc_2p([0,-15],[0,15],15,-1,20)+[[-30,15]]
p6=l_cir_ip([[-30,-15+10.5],[0,-15+10.5]],circle(7.5))
p7=l_cir_ip([[-30,15-10.5],[0,15-10.5]],circle(7.5))
sec4=[[-30,-15+10.5]]+arc_long_2p(p6[0],p7[0],7.5,-1,30)+[[-30,15-10.5]]

sec5=circle(6)
path1=cr(pts1([[0,-15.1],[0,4.6],[-3,0],[0,21],[3,0],[0,4.6]]),5)
sol2=translate([-30+12,0,11.25],q_rot(['x-90'],prism(sec5,path1)))


sec6=[[25.5+9,-15.1]]+arc_2p([25.5+9,0],[25.5,0],4.5,-1)+[[25.5,-15.1]]
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

difference(){{
{swp_c(flip(sol))}
linear_extrude(22.5)polygon({sec4});
{swp(flip(sol1))}
linear_extrude(22.5)polygon({sec6});

}}
difference(){{
linear_extrude(22.5)
difference(){{
polygon({sec3});
polygon({sec4});
}}
{swp(sol2)}
}}

''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.59.32%20PM.png](attachment:Screenshot%202023-01-15%20at%209.59.32%20PM.png)

# %%
# example of function l_cir_ip(line, cir)
p0=[-30,-15+10.5]
p1=[0,-15+10.5+10]
line=[p0,p1]
cir=circle(7.5)
p2=l_cir_ip(line,cir)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 

# %p_line({cir},.1);
# %p_line({[p0,p1]},.1);
color("magenta")points({[p0,p1]},.5);
color("cyan")points({[p2[0]]},.5);

''')

# %%
cir=circle(10,[-10,30])
line=[[-4.5,0],[-4.5,60]]
p0=l_cir_ip(line,cir)
arc1=arc_long_2p(p0[1],p0[0],10,-1,50)
p1=[[0,60,0],[0,35,4.5]]+c2t3(arc1)+[[0,25,4.5],[0,0,0],
                                     [-45,0,0],[-45,60,0]]
sec=cr(p1,10)

p2=[[0,60,0],[0,35,4.5]]+c2t3(arc1)+[[0,25,4.5],[0,0,0],
                                     [45,0,0],[45,60,0]]
sec1=cr(p2,10)
with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
linear_extrude(10)
difference(){{
polygon({sec});

translate([-40,5,0])
square([5,49]);
}}

color("cyan")
//translate([25,0,0])
linear_extrude(10)
difference(){{
polygon({sec1});
translate([35,5,0])
square([5,49]);
translate([-10,30,0])
circle(5,$fn=100);
}}
''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.57.34%20PM.png](attachment:Screenshot%202023-01-15%20at%209.57.34%20PM.png)

# %%
p0=[[0,0,1],[62,0,1],[62,11,1],[62-12,11,1]]+ \
c2t3(arc_2p([62-12,11],[62-12-12,11],6,1,62))[3:-3]+ \
[[62-12-12,11,1],[62-12-12-4,11,1]]+ \
c2t3(arc_2p([62-12-12-4,11],[62-12-12-4-12,11],6,1,62))[3:-3]+ \
[[62-12-12-4-12,11,1],[62-12-12-4-12-4,11,1]]+ \
c2t3(arc_2p([62-12-12-4-12-4,11],[62-12-12-4-12-4-12,11],6,1,62))[3:-3]+ \
[[62-12-12-4-12-4-12,11,1],[62-12-12-4-12-4-12-6,11,1]]

sec=cr(p0,10)

sol=translate([3,0,0],q_rot(['x90','z90'],linear_extrude(sec,105)))

sec1=cr(pts1([[0,0,1],[110,0,1],[0,62,1],[-110,0,1]]),10)
path1=cr(pts1([[-4,0,0],[4,0,1],[0,11,1],[-4,0,1],[0,-8,1],[-4,0,0]]),10)

sol1=prism(sec1,path1)

sec2=cr(pts1([[0,0,1],[20,0,1],[0,50,1],[-20,0,1]]),10)
path2=cr(pts1([[-2,0,0],[2,0,1],[0,8,1],[1,0,0],[0,5,0]]),10)
sol2=translate([28,3,3],prism(sec2,path2))

sec3=circle(6,s=120)
path3=cr(pts1([[0,-1],[0,1,1],[1,0],[0,20],[-1,0,1],[0,1]]),10)
sol3=prism(sec3,path3)
sol3=translate([28,12,11],q_rot(['y90'],sol3))

sec4=[[-8,6,1],[-6,6,1]]+c2t3(arc_2p([-6,6],[6,6],6,-1,60))[3:-3] \
+[[6,6,1],[8,6,1],[8,-3,1],[-8,-3,1]]
sec4=c2t3(cr(sec4,10))
surf1=[translate([0,0,-2],sec4),translate([0,0,10],sec4)]

sec5=[[-10,0],[10,0]]
path5=cytz(cr(pts1([[0,-5],[0,11.1,1],[2,0]]),10))

surf2=q_rot(['z90','x-90'],surf_extrude(sec5,path5))
# surf2=[[-10,-5,1],[10,-5,1]],[[-10,10,1],[10,10,1]]

fillet1=translate([4,6+6,5],q_rot(['x90','z90'],fillet_surf2sol_co(surf2,surf1,1,10,1)))

fillet2=translate([110-4,6+6,5],q_rot(['x90','z-90'],fillet_surf2sol_co(surf2,surf1,1,10,1)))


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
    include<dependencies2.scad>
    

difference(){{
union(){{
{swp(sol)}
{swp(sol1)}
}}
{swp(sol2)}

color("blue")
translate([5,55,11-.34])
linear_extrude(.35)
text("5mm x 0.8",font="Fontdiner Swanky",size=5,halign="left");

for(i=[0:16:32])
translate([0,i,0])
{swp(sol3)}
}}


/*
for(i=[0:16:32])
translate([0,i,0]){{
{swp(fillet1)}
{swp(fillet2)}
}}
*/

''')

# %%
a=circle(5,s=200)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>
points({a},.2);
color("blue")points({min_d_points(a,1)},.2);

''')

# %%
t0=time.time()
r=-2
# sec=cr(pts1([[0,0,1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),10)
sec=circle(10,s=200)
sec1=offset(sec,r)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad> 
p_line({sec},.05);

color("magenta")p_line({sec1},.05);
''')   
    
t1=time.time()
t1-t0
# Out:
# 0.0744471549987793

# %%
# beware before running this , it takes around 450 sec to run


t0=time.time()

stages =200

stage_height = 1.25

rad = 50

f1 = 25

f2 = 25

phase1 = 0

phase2 = 180

height_depth=5

depth1 = 20

depth2 = 20

thickness = 2

bottom_thickness = 3

myslices = 5

angle_step=.5

var=1

def pauw(x,p):
    return sign(x)*abs(x)**p

def f(i,stages):
    return sin(d2r(i/stages * 120))**2 * 7 + 1

def a(i,stages,var,height_depth):
    return (sin(d2r((i/stages*360*f(i,stages))%360)) * 0.5 + 0.5) * (var * height_depth)


# generate outer points

# points_base = [for (i = [0:1:stages]) 
#                let(f = sin(i/stages * 120)^2 * 7 + 1, var = 1 , a=((sin((i/stages*360*f)%360) * 0.5 + 0.5) * (var * height_depth))) 
#                [for(j = [0:angle_step:360-angle_step]) 
#                 [sin(j) * (rad+a+(pauw(sin(j *f1+phase1),0.5)*0.5+0.5)*depth1*i/stages+(pauw(sin(j *f2+phase2),0.5)*0.5+0.5)*depth2*(1-i/stages)), 
#                  cos(j) *(rad+a+(pauw(sin(j *f1+phase1),0.5)*0.5+0.5)*depth1*i/stages+(pauw(sin(j *f2+phase2),0.5)*0.5+0.5)*depth2*(1-i/stages)),
#                  i*stage_height]]]

points_base=[[
    [
        sin(d2r(j)) * (rad+a(i,stages,var,height_depth)+(pauw(sin(d2r(j *f1+phase1)),0.5)*0.5+0.5)*depth1*i/stages+(pauw(sin(d2r(j *f2+phase2)),0.5)*0.5+0.5)*depth2*(1-i/stages)),
        cos(d2r(j)) * (rad+a(i,stages,var,height_depth)+(pauw(sin(d2r(j *f1+phase1)),0.5)*0.5+0.5)*depth1*i/stages+(pauw(sin(d2r(j *f2+phase2)),0.5)*0.5+0.5)*depth2*(1-i/stages)),
        i*stage_height
    ]
    for j in arange(0,360,angle_step)] for i in range(stages+1)]


p1,p2=[],[]
for i in range(stages):
    points_base1=flip(c3t2(points_base[i])) if cw(c3t2(points_base[i]))==1 else c3t2(points_base[i])
    points_base2=offset(points_base1,-2)
    p1.append(translate([0,0,i*stage_height],points_base1))
    p2.append(translate([0,0,i*stage_height],points_base2))
    
sol=swp_prism_h(p1,p2)

sol1=[p1[0],p1[2]]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''

{swp_c(sol)}
{swp(sol1)}
''')   
    
t1=time.time()
t1-t0

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.53.30%20PM.png](attachment:Screenshot%202023-01-15%20at%209.53.30%20PM.png)

# %%
# example of function wrap_around(sec,path)

sec=m_points(cr(pts1([[-10,0,1],[20,0,1],[0,15,1],[-10,10,2],[-10,-10,1]]),20),.2)

l1=c3t2(translate([-.0005,5,0],m_points(square([.001,10]),.1)))

sec2=cpo([sort_points(sec,l1),sec])
sec2=cpo([ls(p,50) for p in sec2])+[sec]

# path1=m_points_o(cr(pts1([[0,0],[15,0,1],[-16,15]]),50),1)
# path1=circle(5,s=200)
# path1=cr(pts1([[0,0],[5,0,1],[0,5,1],[3,0,1],[0,-5,1],[10,0]]),10)
path1=[[i,.3*sin(d2r(i*100))] for i in linspace(0,50,200)]
path3=q_rot(['x90','z90'],path1)

sec3=[wrap_around(p,path3) for p in sec2]
sec3=flip(sec3)
sec4=surf_offset(sec3,.25)

sol=flip(sec3)+sec4+[flip(sec3)[0]]

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

//for(p={sec4})p_line3dc(p,.05);
{swp_c(sol)}

''')

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.50.19%20PM.png](attachment:Screenshot%202023-01-15%20at%209.50.19%20PM.png)

# %%
# example of function wrap_around(sec,path)

p0=[15,0]
p1=[15,45]
cir1=circle(7.5,[0,75-7.5])
p2=p_cir_t(p1,cir1)
p4=[-15,45]
p3=cir_p_t(cir1,p4)
arc1=arc_2p(p2,p3,7.5,-1,45)
p5=[-15,0]
p0,p1,arc1,p4,p5=[[15,0,0]],[[15,45,1]],c2t3(arc1),[[-15,45,1]],[[-15,0,0]]
sec=cr(p0+p1+arc1+p4+p5,10)
sec=m_points(sec,.5)

l1=c3t2(translate([-.0005,5,0],m_points(square([.001,50]),.2)))
sec1=cpo([sort_points(sec,l1),sec])
sec1=cpo([ls(p,20) for p in sec1])+[sec]

path=cr(pts1([[0,0],[45,0,1],[40*cos(d2r(30)),40*sin(d2r(30))]]),10)
path=q_rot(['x90','z90'],path)

surf1=flip([wrap_around(p,path) for p in sec1])
surf2=surf_offset(surf1,-4)
sol=translate([0,0,9+4],q_rot(['z-90'],flip(surf1)+surf2+[flip(surf1)[0]]))

sec2=[circle(.5,[0,75-7.5]),circle(3.75,[0,75-7.5])]
surf3=flip([wrap_around(p,translate([0,0,.001],path)) for p in sec2])
surf4=surf_offset(surf3,-4.1)
sol1=translate([0,0,9+4],q_rot(['z-90'],flip(surf3)+surf4))


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

difference(){{
{swp_c(flip(sol))}
color("blue"){swp(flip(sol1))}
}}

''')

# %%
# example of function wrap_around(sec,path) work flow

def wrap_around(sec,path):
    sec=sec if array(sec).shape[1]==3 else c2t3(sec)
    path=array(path)
    dy=[0]+[l_len([path[i],path[i+1]]) for i in range(len(path)-1)]
    v1=[path[i+1]-path[i] for i in range(len(path)-1)]
    dy,v1=array(dy),array(v1)
    y=dy.cumsum()
    l1=array([p for p in array(sec)[:,1]])

    sec1=[]
    for n in range(len(sec)):
        m=arange(len(y))[y>l1[n]][0]
        m=0 if m-1<0 else m-1
        l2=l1[n]-y[m]
        l2=l1[n] if l2<0 else l2
        p2=path[m]+v1[m]*l2/dy[m+1]+array([sec[n][0],0,sec[n][2]])
        sec1.append(p2.tolist())
    return sec1

sec=m_points(cr(pts1([[-10,0,1],[20,0,1],[0,15,1],[-10,10,2],[-10,-10,1]]),20),.2)


path1=cr(pts1([[0,0],[15,0,1],[-16,15]]),50)
path2=circle(5,s=200)
path3=cr(pts1([[0,0],[5,0,1],[0,5,1],[3,0,1],[0,-5,1],[10,0]]),10)
path1=q_rot(['x90','z90'],path1)
path2=q_rot(['x90','z90'],path2)
path3=q_rot(['x90','z90'],path3)

sec1=wrap_around(sec,path1)
sec2=wrap_around(sec,path2)
sec3=wrap_around(sec,path3)

path4=cr(pts1([[6,2],[-6,0,1],[0,-2,1],[25,0]]),10)
path4=q_rot(['x90','z90'],path4)

sec4=translate([0,9,0],q_rot(['z-45'],sec1))
sec4=wrap_around(sec4,path4)

sec5=translate([0,9,0],q_rot(['z90'],translate([0,-9,0],sec4)))
sec5=wrap_around(sec5,path4)

sec6=q_rot(['z-45'],translate([0,-9,0],sec5))


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

translate([30,40,0]){{
p_line3d({path2},.1);
color("magenta")p_line3dc({sec2},.1);}}

translate([30,60,0]){{
p_line3d({path3},.1);
color("magenta")p_line3dc({sec3},.1);}}

color("blue")p_line3dc({sec},.1);
translate([0,30,0]){{
color("blue")p_line3d({path1},.1);
color("magenta")p_line3dc({sec1},.1);}}


translate([0,50,0]){{
color("blue")p_line3d({path4},.1);
color("magenta")p_line3dc({sec4},.1);}}

translate([0,80,0]){{
color("blue")p_line3d({path4},.1);
color("magenta")p_line3dc({sec5},.1);}}

translate([0,110,0]){{
//p_line3d({path4},.1);
color("magenta")p_line3dc({sec6},.1);}}

''')

# %%
# wrap_around example 4
t0=time.time()

sec0=cr(pts1([[-10,0,1],[20,0,1],[0,15,1],[-10,10,2],[-10,-10,1]]),20)
cp=array(offset(sec0,-10)).mean(0).tolist()
sec=m_points(cr(pts1([[-10,0,1],[20,0,1],[0,15,1],[-10,10,2],[-10,-10,1]]),20),.2)
sec1=cpo([sort_points(sec,[cp]),sec])
sec1=cpo([ls(p,50) for p in sec1 ])+[sec]


path1=cr(pts1([[0,0],[15,0,1],[-16,15]]),50)
path1=q_rot(['x90','z90'],path1)


sec1=[wrap_around(p,path1) for p in sec1]

path4=cr(pts1([[7,5],[-7,-5,1],[45,0]]),10)
path4=q_rot(['x90','z90'],path4)

sec2=translate([0,9,0],q_rot(['z-45'],sec1))
sec2=[wrap_around(p,path4) for p in sec2]

sec3=translate([0,9,0],q_rot(['z90'],translate([0,-9,0],sec2)))
sec3=[wrap_around(p,path4) for p in sec3]

sec3=q_rot(['z-45'],translate([0,-9,0],sec3))
sec4=surf_offset(flip(sec3),.5)
sol=sec3+sec4+[sec3[0]]
sol=translate([0,3,0],sol)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

{swp(sol)}


''')  
t1=time.time()
t1-t0
# Out:
# 7.090651988983154

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.39.19%20PM.png](attachment:Screenshot%202023-01-15%20at%209.39.19%20PM.png)

# %%
# another approach to resurface a section

sec=cr(pts1([[0,0,.2],[8,3,3],[5,7,1],[-8,0,2],[-5,20,1]]),20)
# sec=cr(pts1([[0,0,1],[7,5,2],[5,7,3],[-5,7,5],[-7,5,5]]),20)
# sec=cr(pts1([[-15,0,2.4],[0,15,3],[30,0,3],[0,-15,2.4],[5,0,2.4],[0,20,7],[-40,0,7],[0,-20,2.4]]),5)
# sec=pts([[0,0],[10,0],[0,5],[-10,0]])

sec1=offset(sec,-4.2)
cp1=array(sec1).mean(0).tolist()
sec1=sort_points(sec,[cp1])
sec2=cpo([sec1,sec])
sec2=cpo([ls([p[0],p[0]+(p[1]-p[0])*2],20) for p in array(sec2)])

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

//p_line({sec},.05);
//p_line({sec1},.05);

points({[cp1]},.2);
for(p={sec2})p_line(p,.05);


''')

# %%
#  ball bearing

sec=cr(pts1([[31,.5,0],[.5,-.5,0],[9.5,0,1],[0,15,1],[-9.5,0,0],[-.5,-.5,0]]),10)
sec1=cr(pts1([[16,.5,0],[.5,-.5],[9,0,0],[0.5,.5,0],[0,14,0],[-.5,.5,0],[-9,0,0],[-.5,-.5,0]]),10)
sec2=circle(7,[28.5,7.5])

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

rotate_extrude($fn=200)
difference(){{
union(){{
polygon({sec});
polygon({sec1});
}}
polygon({sec2});
}}

for(i=[0:360/12:359])
rotate([0,0,i])
translate([28.5,0,7.5])
sphere(6.8,$fn=100);

''')

# %%
# mobile phone stand

t0=time.time()
sec1=cr(pts1([[-75,20,2],[75,-20,500],[75,20,2],[0,70,2],[-75,7,500],[-75,-7,2]]),30)
cp1=array(offset(sec1,-35)).mean(0)
sec1=m_points(sec1,.5)
sec2=cpo([sort_points(sec1,[cp1]),sec1])
sec2=cpo([ls(p,60)for p in sec2])+[sec1]
path1=cr(pts1([[0,60*sin(d2r(60)),0],[60*cos(d2r(-60)),60*sin(d2r(-60)),5+1],[15+10,0,4+1],[50*cos(d2r(120)),50*sin(d2r(120))]]),50)
path1=path1
path1=q_rot(['x90','z90'],path1)

surf1=[wrap_around(p,path1) for p in sec2]
surf2=surf_offset(flip(surf1),4)
sol=surf1+surf2
p0,p1,p2,p3=flip(surf1)[0],flip(surf1)[2],surf2[0],surf2[2]
fillet1=convert_3lines2fillet(p0,p1,p2,1,10)
fillet1=fillet1
# fillet1=[scl3dc(p,1.1) for p in fillet1]

fillet2=convert_3lines2fillet(p2,p0,p3,1,10)
fillet2=fillet2
# fillet2=[scl3dc(p,1.1) for p in fillet2]

sol=surf1[:-3]+cpo(fillet1)[1:]+cpo(fillet2)[1:]+surf2[3:]

sec1=cr(pts1([[-70,20,2],[70,-20,500],[70,20,2],[0,55,2],[-140,0,2]]),30)
cp1=array(offset(sec1,-25)).mean(0)
sec1=m_points(sec1,.5)
sec2=cpo([sort_points(sec1,[cp1]),sec1])
sec2=cpo([ls(p,60)for p in sec2])+[sec1]

path2=cr(pts1([[0,0],[70,0,4+1],[100*cos(d2r(120)),100*sin(d2r(120))]]),50)
path2=q_rot(['x90','z90'],path2)
surf1=[wrap_around(p,path2) for p in sec2]
surf2=surf_offset(flip(surf1),4)
sol1=surf1+surf2

p0,p1,p2,p3=flip(surf1)[0],flip(surf1)[2],surf2[0],surf2[2]
fillet3=convert_3lines2fillet(p0,p1,p2,1,10)
fillet3=fillet3
# fillet3=[scl3dc(p,1.1) for p in fillet3]

fillet4=convert_3lines2fillet(p2,p0,p3,1,10)
fillet4=fillet4
# fillet4=[scl3dc(p,1.1) for p in fillet4]

sol1=surf1[:-3]+cpo(fillet3)[1:]+cpo(fillet4)[1:]+surf2[3:] 

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>

translate([0,40-4.625,0])
{swp(sol)}

{swp(sol1)}

''')  
t1=time.time()
t1-t0
# Out:
# 11.68668818473816

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.36.17%20PM.png](attachment:Screenshot%202023-01-15%20at%209.36.17%20PM.png)

# %%
# back camera clamp

res=.5
sec=cr(pts1([[-37/2,0,.5],[37,0,.5],[0,15,.5],[-5,24,13.5],[-27,0,13.5],[-5,-24,.5]]),20)
cp1=array(offset(sec,-17)).mean(0)
sec1=[sort_points(m_points(sec,res),[cp1])]+[m_points(sec,res)]
sec2=cpo([ls(p,20) for p in cpo(sec1)])+[m_points(sec,res)]

path=cr(pts1([[0,0],[15,0,3.5],[15,41.21]]),10)
path=q_rot(['x90','z90'],path)

sec3=[wrap_around(p,path) for p in sec2]
sec4=surf_offset(flip(sec3),2)

sol=sec3+sec4

sec5=translate([0,0,-1],c2t3([circle(.1,[0,28])]+[circle(9,[0,28])]))
sec5=[wrap_around(p,path) for p in sec5]
sec6=surf_offset(flip(sec5),4)

sol1=sec5+sec6

cyl1=cylinder(d=4,h=5)

slit=q_rot(['x70'],translate([-.5,15,-17],linear_extrude(square([1,20]),10)))

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
include<dependencies2.scad>
rotate([-70,0,0])
translate([0,-15,0])
difference(){{
{swp(sol)}
{swp(sol1)}

for(i=[-27/2,27/2])
translate([i,5,-2])
{swp(cyl1)}

{swp(slit)}
}}
''') 

15*tan(d2r(70))
# Out:
# 41.21216129181932

# %% [markdown]
# ![Screenshot%202023-01-15%20at%209.28.44%20PM.png](attachment:Screenshot%202023-01-15%20at%209.28.44%20PM.png)
