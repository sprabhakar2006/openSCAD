# %%
from openscad1 import *

# %%
p0,p1,p2=[0,775],[0,480],[480/sin(d2r(60))*cos(d2r(60)),0]
p3=array(p2)+[420,0]
p4=p3+q_rot2d(30,[100,0])
p5=p4+q_rot2d(120,[75,0])

p0,p1,p2,p3,p4,p5
l1=p5[0]-(p2[0]+290)
l2=320
l3=p5[1]-sqrt(l2**2-l1**2)
p6=array([p2[0]+290,l3])
p7=array(p2)+[-255,190]
l1=path_offset_n([p0,p1],-30)
# arc_1=p6+[q_rot2d(i,p5-p6) for i in linspace(0,90,30)]
# arc_1=arc_1.tolist()
p3,p4,p5,p6,p7=array([p3,p4,p5,p6,p7]).tolist()

arc_1=arc_with_start_pt_and_cp(p5,p6,120,50)
arc_2=arc(270,-90,180,p7,s=50)
arc_3=two_cir_tarc(arc_1,arc_2,70)

arc_4=fillet_line_circle(l1,arc_2,100,-1)
p6=arc_3[0]
p7=arc_3[-1]
p8=arc_4[-1]
p9=arc_4[0]

sec=[p0,p1,p2,p3]+equidistant_path([p3,p4],10)+arc_2p(p5,p6,320,-1,50)+arc_2p(p6,p7,70,1,20)+ \
arc_2p(p7,p8,270,-1,50)+arc_2p(p8,p9,100,1,20)+equidistant_path([arc_4[0],l1[0]],20)
sec=remove_extra_points(array(sec).round(5))
sec_0=equidistant_pathc(sec,500)
sec1=c2t3(sec)
p_0=array(sec1[0])+[0,0,100]
p_1=array(sec1[1])+[0,0,180]
p_2=array(sec1[2])+[0,0,122]
p_3=array(sec1[3])+[0,0,200]
arc_01=arc_2p_3d([1,0,0],p_0,p_1,800,1,s=50)
arc_02=arc_2p_3d(nv([sec1[1],sec1[2],p_1]),p_1,p_2,750,1,s=50)
arc_03=arc_2p_3d([0,1,0],p_2,p_3,840,1,s=50)

surf_1=SurfaceFrom3LinesInDifferentPlanes(extend_arc3d(arc_03,15),flip(arc_02),extend_arc3d(flip(arc_01),10))

sol_1=linear_extrude(sec,300)
sol_2=surf_base(surf_1,0)

a=q_rot(['x90','z120'],q_rot2d(-90,pts([[0,0],[-30,0],[-50,-50],[-50,0],[-50,50],[-70,0]])))
b=translate([770,100,0],bezier(a,100))
b=flip(mirror(b,[0,0,1],[0,0,0]))+b
v1=q_rot(['z30'],[[-300,0,0]])[0]
c=translate(v1,b)
s_1=[b,c]
v2=q_rot(['z30'],[[0,-70,0]])[0]
s_2=translate(v2,s_1)
a,b,c,d=s_1+s_2
sol_3=flip([a+flip(c),b+flip(d)])
sec_1=path_offset(sec[1:14],-30)+path_offset(sec[14:-20],1)

sol_4=linear_extrude(sec_1,400)
surf_2=translate([0,0,-30],surf_1)
sol_5=surf_base(surf_2,-30)
v3=q_rot(['z30'],[[0,30,0]])[0]
sol_6=translate(v3,sol_3)

arc_02_01=mirror(arc_02,[0,0,1],[0,0,0])
arc_04=arc_2p_3d([1,0,0],arc_02_01[0],arc_02[0],400,-1,40)
arc_05=arc_2p_3d([0,1,0],arc_02_01[-1],arc_02[-1],150,1,40)
m_0=mid_point(arc_04)
m_1=mid_point(arc_05)
p_5,p_4=[150,100,0],[125,200,0]
l_1=bezier([m_0,p_4,p_5,m_1],51)
surf_3=convert_3lines2surface(arc_02_01,l_1,arc_02,40)

l_1=equidistant_path(arc_02,40)
l_2=equidistant_path(cpo(surf_3)[-5],40)
l_3=flip(equidistant_path(cpo(surf_1)[5],40))
fillet_1=convert_3lines2fillet(l_2,l_3,l_1)
fillet_1=solid_from_fillet(fillet_1,-40)

l_1=equidistant_path(extend_arc3d(flip(arc_03),10),50)
l_2=equidistant_path(translate([0,0,-30],l_1),50)
l_3=equidistant_path(extend_arc3d(flip(surf_1[2][:-14]),10),50)
fillet_2=convert_3lines2fillet(l_2,l_3,l_1)
fillet_2=solid_from_fillet(fillet_2,40)

l_1=equidistant_path(extend_arc3d(flip(extend_arc3d(surf_3[-1],10)),10),50)
l_2=equidistant_path(extend_arc3d(flip(extend_arc3d(surf_3[-5],10)),10),50)
l_3=equidistant_path(translate([30,0,0],l_1),50)
fillet_3=convert_3lines2fillet(l_2,l_3,l_1)
fillet_3=solid_from_fillet(fillet_3,-40)

l_1=ip_sol2sol(sol_1,sol_3)
l_2=translate([-30,0,0],l_1)
v_3=q_rot(['z30'],[[30,0,0]])[0]
l_3=translate(v_3,l_1)
fillet_4=convert_3lines2fillet(l_2,l_3,l_1)
fillet_4=solid_from_fillet(fillet_4,40)
l_1=slice_sol([equidistant_path(a,30),equidistant_path(b,30)],20)
l_1=ip_sol2sol(surf_1,cpo(l_1),-1)

v_4=q_rot(['z120'],[[30,0,0]])[0]
l_2=translate(v_4,l_1)
l_2=project_line_on_surface(l_2,surf_1)
surf_4=slice_sol([a,b],10)
l_3=translate([0,0,-30],l_1)
l_3=project_line_on_surface(l_3,surf_4)
l_1=equidistant_path(l_1,15)
l_2=equidistant_path(l_2,15)
l_3=equidistant_path(l_3,15)

fillet_5=convert_3lines2fillet(l_3,l_2,l_1)
fillet_5=solid_from_fillet(fillet_5,40)

l_1=project_line_on_surface(c2t3(sec[13:]),surf_1,[0,0,1])
l_1=equidistant_path(remove_extra_points(array(l_1).round(4)),150)
l_2=project_line_on_surface(c2t3(path_offset_n(sec[13:],15)),surf_1,[0,0,1])
l_2=flip(equidistant_path(remove_extra_points(array(l_2).round(4)),150))
l_3=translate([0,0,-15],l_1)

fillet_6=convert_3lines2fillet(l_3,l_2,l_1)
fillet_6=solid_from_fillet(fillet_6,-40)

l_1=surf_3[0]
l_2=surf_3[3]
l_3=translate([0,40,0],l_1)
fillet_7=convert_3lines2fillet(l_3,l_2,l_1)
fillet_7=solid_from_fillet(fillet_7,40)

l_1=project_line_on_surface(c2t3(sec_1[13:-7]),surf_2,[0,0,1])
l_2=project_line_on_surface(c2t3(path_offset(sec_1[13:-7],-15)),surf_2,[0,0,1])
l_3=translate([0,0,15],l_1)
fillet_8=convert_3lines2fillet(l_2,l_3,l_1)
fillet_8=solid_from_fillet(fillet_8,-40)

l_1=equidistant_path(sec_1[:12],100)
l_2=project_line_on_surface(c2t3(path_offset(l_1,-15)),surf_2,[0,0,1])
l_1=project_line_on_surface(c2t3(l_1),surf_2,[0,0,1])
l_3=translate([0,0,-15],l_1)
fillet_9=convert_3lines2fillet(l_2,l_3,l_1)

p0=c2t3(sec_1[1])
p1=project_line_on_surface([p0],surf_2,[0,0,1])[0]
p2=mirror([p1],[0,0,1],[0,0,0])[0]
l_1=[p1,p2]
v1=q_rot(['z120'],[[30,0,0]])[0]
l_2=translate(v1,l_1)
l_3=translate([30,0,0],l_1)
fillet_10=convert_3lines2fillet(l_2,l_3,l_1)

p0=c2t3(sec_1[0])
p1=project_line_on_surface([p0],surf_2,[0,0,1])[0]
p2=mirror([p1],[0,0,1],[0,0,0])[0]
l_1=[p1,p2]
v1=q_rot(['z300'],[[30,0,0]])[0]
l_2=translate([0,30,0],l_1)
l_3=translate(v1,l_1)
fillet_11=convert_3lines2fillet(l_2,l_3,l_1)

# arc_01=path_offset_3d(arc_01,10)
l_1=[arc_01[0],mirror([arc_01[0]],[0,0,1],[0,0,0])[0]]

l_2=fillet_line_circle_internal_3d(l_1,arc_01,150,-1,1)[1:]
l_3=mirror(l_2,[0,0,1],[0,0,0])
# l_1=flip(arc_01[20:-5])+flip(l_2)+l_3+mirror(arc_01[20:-5],[0,0,1],[0,0,0])
l_1=flip(l_2)+l_3
l_2=translate([15,0,0],l_1)
l_3=path_offset_3d(l_1,-15)
fillet_12=convert_3lines2fillet(l_2,l_3,l_1)
# fillet_12=solid_from_fillet(fillet_12,-30)
fillet_13=[mirror(p,[1,0,0],[15,0,0]) for p in fillet_12]
fillet_12=flip(cpo(fillet_12)[:-1])
fillet_13=cpo(fillet_13)[:-1]
fillet_12=fillet_12+fillet_13[1:]
fillet_12=solid_from_fillet(fillet_12,-100)

l_1=arc_01[16:]
l_2=translate([15,0,0],l_1)
l_3=path_offset_3d(l_1,-15)
fillet_13=convert_3lines2fillet(l_3,l_2,l_1)
fillet_13=solid_from_fillet(fillet_13,-20)

a=q_rot(['x90','z120'],q_rot2d(-90,pts([[0,0],[-30,0],[-50,-50],[-50,0],[-50,50],[-70,0]])))
b=translate([770,100,0],bezier(a,100))
b=flip(mirror(b,[0,0,1],[0,0,0]))+b

l_1=project_line_on_surface(c2t3(sec[13:15]),surf_1,[0,0,1])
l_2=mirror(l_1,[0,0,1],[0,0,0])
s_10=[l_1,l_2]
v_1=q_rot(['z30'],[[-15,0,0]])[0]
v_2=q_rot(['z120'],[[15,0,0]])[0]
l_1=project_line_on_surface(b,s_10,v_1)
l_2=translate(v_2,l_1)
l_3=translate(v_1,l_1)
fillet_14=convert_3lines2fillet(l_3,l_2,l_1)
fillet_14=solid_from_fillet(fillet_14,40)

l_2=translate(v_2,l_1)
l_1=translate(v_2,l_2)
l_3=translate(v_1,l_1)
fillet_15=convert_3lines2fillet(l_3,l_2,l_1)
fillet_15=solid_from_fillet(fillet_15,-40)[10:-10]

pl_1=translate([0,30,0],plane([0,1,0],2500))
l_2=project_line_on_surface(l_1,pl_1,v_1)
l_3=translate([-30,0,0],l_2)
v_3=q_rot(['z30'],[[30,0,0]])[0]
l_1=translate(v_3,l_2)

fillet_16=convert_3lines2fillet(l_1,l_3,l_2)

l_1=equidistant_path(sec[13:15],10)[8:]
l_2=path_offset(l_1,-15)
l_1=project_line_on_surface(c2t3(l_1),surf_2,[0,0,1])
l_2=project_line_on_surface(c2t3(l_2),surf_2,[0,0,1])
l_3=translate([0,0,15],l_1)
fillet_17=convert_3lines2fillet(l_2,l_3,l_1)
fillet_17=solid_from_fillet(fillet_17,-9)
with open('trial.scad','w+') as f:
    f.write(f'''
    include<dependencies2.scad>
  rotate([90,0,0])
   render(){{
    difference(){{
    union(){{
    difference(){{
    union(){{
    intersection(){{
    {swp(sol_1)}
    {swp(sol_2)}
    }}
    
    mirror([0,0,1])
    intersection(){{
    {swp(sol_1)}
    {swp(sol_2)}
    }}
    }}
    {swp(sol_3)}
    {swp(fillet_8)}
    mirror([0,0,1])
    {swp(fillet_8)}
    }}
    }}
    
    union(){{
    difference(){{
    union(){{
    intersection(){{
    {swp(sol_4)}
    {swp(sol_5)}
    }}
    
    mirror([0,0,1])
    intersection(){{
    {swp(sol_4)}
    {swp(sol_5)}
    }}
    }}
    {swp(sol_6)}
    }}
    }}

 {swp(fillet_1)}
 mirror([0,0,1])
 {swp(fillet_1)}
 {swp(fillet_2)}
 mirror([0,0,1])
 {swp(fillet_2)}
 {swp(fillet_3)}
 {swp(fillet_4)}
 mirror([0,0,1])
 {swp(fillet_4)}
{swp(fillet_5)}
mirror([0,0,1])
{swp(fillet_5)}
{swp(fillet_6)}
mirror([0,0,1])
{swp(fillet_6)}
{swp(fillet_7)}
{swp(fillet_12)}
{swp(fillet_13)}
mirror([0,0,1])
{swp(fillet_13)}
{swp(fillet_14)}
{swp(fillet_15)}
{swp(fillet_17)}
mirror([0,0,1])
{swp(fillet_17)}




    }}
    difference(){{
    {swp(surf_3)}
     {swp(fillet_1)}
     mirror([0,0,1])
 {swp(fillet_1)}
 {swp(fillet_2)}
 mirror([0,0,1])
 {swp(fillet_2)}
 {swp(fillet_3)}
 {swp(fillet_4)}
 mirror([0,0,1])
 {swp(fillet_4)}
 {swp(fillet_7)}
    }}
    
  {swp(fillet_9)}
  mirror([0,0,1])
  {swp(fillet_9)}
  {swp(fillet_10)}
  {swp(fillet_11)}
  {swp(fillet_16)}
  }}
    ''')
