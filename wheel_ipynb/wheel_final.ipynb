# %%
from openscad import *

# %%
# method 1

initial_time=time.time()
path7=cr(pts1([[0,0],[0,5],[-13,20],[0,20],[-12,20],[0,78],[12,20],[0,64],[13,20],[0,5]]),5)
sec7=circle(245,s=72)

sec10=cr(pts1([[-100,0],[100,30,500],[100,-30]]),20)
path10=trns([0,0,190],q_rot(["y-5","z-15"],cytz(cr(pts1([[0,0],[130,30,1000],[260,-10,0]]),20))))

sec1=cr([[300,0,7], [0,0,10] , [300*cos(-30*pi/180),300*sin(-30*pi/180),7]]+c2t3(arc(300,-30,0,[0,0],s=10)[1:-1]),10)
sol1=l_extrude(sec1,300)
surf1=surf_extrude(sec10,path10)
sec2=cr([[300,0,1], [0,0,15] , [300*cos(-30*pi/180),300*sin(-30*pi/180),1]]+c2t3(arc(300,-30,0,[0,0],s=10))[1:-1],20)
sol2=trns([50*cos(-15*pi/180),50*sin(-15*pi/180),0],l_extrude(sec2,300))
sec3=cr([[300,0,1], [0,0,15] , [300*cos(-30*pi/180),300*sin(-30*pi/180),1]]+c2t3(arc(300,-30,0,[0,0],s=10))[1:-1],20)
sol3=trns([50*cos(-15*pi/180),50*sin(-15*pi/180),0],l_extrude(m_points(sec3,10),300))
ip1=ip_surf(surf1,sol3)
sec4=cr(pts1([[3,0,0],[0,3,1.5],[-3,0,1.5],[0,-3,0]]),10)
bead1=p_extrude(sec4,ip1)


sec=cr(pts1([[-100,0],[100,30,500],[100,-30]]),20)
path=trns([0,0,217],q_rot(["y10","z15"],cytz(cr(pts1([[0,0],[130,30,1000],[260,-10,0]]),20))))

surf=surf_extrude(sec,path)
sec5=cr([[300*cos(30*pi/180),300*sin(30*pi/180),7],[0,0,10],[300,0,7]]+c2t3(arc(300,0,30,[0,0],s=10))[1:-1],10)
sol4=l_extrude(sec5,300)
sec6=cr([[300*cos(30*pi/180),300*sin(30*pi/180),10],[0,0,30],[300,0,10]]+c2t3(arc(300,0,30,[0,0],s=10))[1:-1],40)
sol5=trns([50*cos(15*pi/180),50*sin(15*pi/180),0],l_extrude(m_points(sec6,10),300))
ip2=ip_surf(surf,sol5)
ip2= remove_extra_points(array(ip2).round(4))
bead2=p_extrudec(sec4,ip2)
cyl1=cylinder(r=15,h=300,cp=[110*cos(15*pi/180),110*sin(15*pi/180)],s=40)
ip3=ip_surf(surf,cyl1)
ip3=remove_extra_points(array(ip3).round(4))
bead3=p_extrudec(sec4,ip3)


sec8=cr(pts1([[0,0],[2.5,0,2.5],[0,45,2.5],[-5,0,2.5],[0,-45,2.5]]),20)
sol6=trns([22,0,205],q_rot(["x90","z90"],l_extrude(m_points(sec8,1),300)))

sec9=circle(245,s=100)
path9=cr(pts1([[2,0],[-2,0,2],[0,5,5],[-13,20,5],[0,20,5],[-12,20,5],[0,78,5],[12,20,5],[0,64,5],[13,20,5],[0,5,2],[2,0]]),5)
sol7=prism(sec9,path9)


sol8=fillet_sol2sol(flip(sol7),sol6,1.5,10,1)


sec11=circle(45,s=100)
path11=cr(pts1([[0,200],[5,0,5],[0,40,5],[-25,15,5],[-24.5,0]]),15)
sol9=prism(sec11,path11)
sol10=fillet_sol2sol(sol9,sol6,1.5,10,0)

sec12=cr([[50,0,4],[0,0,15],[50*cos(-30*pi/180),50*sin(-30*pi/180),4]]+c2t3(arc(50,-30,0,[0,0],10))[1:-1],15)
sol12=l_extrude(sec12,300)
sol13=ipf(surf1,sol12,4,10,0)
sol14=q_rot(["z30"],sol12)
sol15=ipf(surf,sol14,4,10,0)
sol16=l_extrude(m_points(offset(sec1,-2.5),10),300)
sol17=ipf(surf1,sol16,4,10,1)
sol18=q_rot(["z30"],sol16)
sol19=ipf(surf,sol18,4,10,1)
sol20=q_rot(["z30"],sol6)
sol21=q_rot(["z30"],sol8)
sol22=q_rot(["z30"],sol10)

sec13=circle(250,s=100)
path12=cr(pts1([[-2,0],[2,0,2],[0,5,5],[-13,20,5],[0,20,5],[-12,20,5],[0,78,5],[12,20,5],[0,64,5],[13,20,5],[0,5,2],[-2,0]]),5)

sol23=prism(sec13,path12)


surf2=trns([0,0,-5],surf1)
sol24=ipf(surf2,sol2,3,10,0)
sol25=ipf(surf2,flip(sol16),4,10,0)
sol26=ipf(surf2,flip(sol12),4,10,1)

surf3=trns([0,0,-5],surf)
sol27=ipf(surf3,flip(sol18),4,10,0)
sol28=ipf(surf3,flip(sol14),4,10,1)

cyl2=cylinder(r=10,h=300,cp=[110*cos(15*pi/180),110*sin(15*pi/180)],s=50)
sol29=[ip_surf(surf3,cyl2)+[ip_surf(surf3,cyl2)[0]]]+ipe(surf3,cyl1,4,10,0)
sol05=trns([50*cos(15*pi/180),50*sin(15*pi/180),0],l_extrude(m_points(offset(sec6,-5),10),300))

sol30=[ip_surf(surf3,sol05)+[ip_surf(surf3,sol05)[0]]]+ipe(surf3,sol5,4,10,0)
sol31=cpo(ipf(surf2,sol3,4,10,0))


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
    
    render(){{
    for(i=[0:60:300])rotate([0,0,i])
    difference(){{
    difference(){{
    intersection(){{
    {swp(surf_extrudef(surf_extrude(sec,path),-5))}
    {swp(sol4)}
    {swp(sol7)}
    }}
    {swp(sol5)}
    {swp(cyl1)}
    
    }}
    {swp(flip(cpo(ipf(surf3,cyl1,4,10,0))))}
    {swp(flip(cpo(ipf(surf3,sol5,4,10,0))))}
    
    }}
    
    
    intersection(){{
        {{for(i=[0:60:360-60])
        rotate([0,0,i])
        {swp_c(sol19)}}}
        {swp(sol7)}
      }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol15)}
    
    
    intersection(){{
        {{for(i=[0:60:360-60])
        rotate([0,0,i])
        {swp_c(sol27)}}}
        {swp(sol7)}
      }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol28)}
    
    for(i=[0:60:300])rotate([0,0,i])
    intersection(){{
    {swp_c(bead2)}
    {swp(sol7)}
        }}
        
    for(i=[0:60:300])rotate([0,0,i]){{
    {swp_c(bead3)}
    }}
    
     
   
    
    
    intersection(){{
    {{for(i=[0:60:300])rotate([0,0,i])
    difference(){{
    intersection(){{
    {swp(surf_extrudef(surf_extrude(sec10,path10),-5))}
    {swp(sol1)}
    
    }}
    {swp(sol2)}
    {swp(flip(sol31))}
    }}}}
    {swp(sol7)}
    
    }}
    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp(bead1)}
    {swp(sol7)}
    }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i]){{
    intersection(){{
    {swp_c(sol25)}
    {swp(sol7)}
    }}
    {swp_c(sol26)}
    }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol13)}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp_c(sol17)}
    {swp(sol7)}
    }}
    

    
    
    for(i=[0:30:360-30])
    rotate([0,0,i])
    intersection(){{
    {swp(sol6)}
    {swp(sol7)}
    }}
    
    for(i=[0:30:360-30])
    rotate([0,0,i]){{
    {swp_c(sol8)}
    {swp_c(sol10)}
    }}
    
    
    
    
    
    difference(){{
    {swp(sol9)}
    {swp(cylinder(r=20,h=300,s=72))}
    
    }}
    
    {swp_c(swp_prism_h(sol23,sol7))}
    
    }}
    
    ''')    
final_time=time.time()
final_time-initial_time

# %%
# method 2

initial_time=time.time()
path7=cr(pts1([[0,0],[0,5],[-13,20],[0,20],[-12,20],[0,78],[12,20],[0,64],[13,20],[0,5]]),5)
sec7=circle(245,s=72)

sec10=cr(pts1([[-100,0],[100,30,500],[100,-30]]),20)
path10=trns([0,0,190],q_rot(["y-5","z-15"],cytz(cr(pts1([[0,0],[130,30,1000],[260,-10,0]]),20))))

sec1=cr([[300,0,7], [0,0,10] , [300*cos(-30*pi/180),300*sin(-30*pi/180),7]]+c2t3(arc(300,-30,0,[0,0],s=10)[1:-1]),10)
sol1=l_extrude(sec1,300)
surf1=surf_extrude(sec10,path10)
sec2=cr([[300,0,1], [0,0,15] , [300*cos(-30*pi/180),300*sin(-30*pi/180),1]]+c2t3(arc(300,-30,0,[0,0],s=10))[1:-1],20)
sol2=trns([50*cos(-15*pi/180),50*sin(-15*pi/180),0],l_extrude(sec2,300))
sec3=cr([[300,0,1], [0,0,15] , [300*cos(-30*pi/180),300*sin(-30*pi/180),1]]+c2t3(arc(300,-30,0,[0,0],s=10))[1:-1],20)
sol3=trns([50*cos(-15*pi/180),50*sin(-15*pi/180),0],l_extrude(m_points(sec3,10),300))
ip1=ip_surf(surf1,sol3)
sec4=cr(pts1([[3,0,0],[0,3,1.5],[-3,0,1.5],[0,-3,0]]),10)
bead1=path_extrude(sec4,ip1)


sec=cr(pts1([[-100,0],[100,30,500],[100,-30]]),20)
path=trns([0,0,217],q_rot(["y10","z15"],cytz(cr(pts1([[0,0],[130,30,1000],[260,-10,0]]),20))))

surf=surf_extrude(sec,path)
sec5=cr([[300*cos(30*pi/180),300*sin(30*pi/180),7],[0,0,10],[300,0,7]]+c2t3(arc(300,0,30,[0,0],s=10))[1:-1],10)
sol4=l_extrude(sec5,300)
sec6=cr([[300*cos(30*pi/180),300*sin(30*pi/180),10],[0,0,30],[300,0,10]]+c2t3(arc(300,0,30,[0,0],s=10))[1:-1],40)
sol5=trns([50*cos(15*pi/180),50*sin(15*pi/180),0],l_extrude(m_points(sec6,10),300))
ip2=ip_surf(surf,sol5)
ip2= remove_extra_points(array(ip2).round(4))
bead2=path_extrudec(sec4,ip2)
cyl1=cylinder(r=15,h=300,cp=[110*cos(15*pi/180),110*sin(15*pi/180)],s=40)
ip3=ip_surf(surf,cyl1)
ip3=remove_extra_points(array(ip3).round(4))
bead3=path_extrudec(sec4,ip3)


sec8=cr(pts1([[0,0],[2.5,0,2.5],[0,45,2.5],[-5,0,2.5],[0,-45,2.5]]),20)
sol6=trns([22,0,205],q_rot(["x90","z90"],l_extrude(m_points(sec8,.25),300)))

sec9=circle(245,s=100)
path9=cr(pts1([[2,0],[-2,0,2],[0,5,5],[-13,20,5],[0,20,5],[-12,20,5],[0,78,5],[12,20,5],[0,64,5],[13,20,5],[0,5,2],[2,0]]),5)
sol7=prism(sec9,path9)


sol8=fillet_sol2sol(flip(sol7),sol6,1.5,10,1)


sec11=circle(45,s=100)
path11=cr(pts1([[0,200],[5,0,5],[0,40,5],[-25,15,5],[-24.5,0]]),15)
sol9=prism(sec11,path11)
sol10=fillet_sol2sol(sol9,sol6,1.5,10,0)

sec12=cr([[50,0,4],[0,0,15],[50*cos(-30*pi/180),50*sin(-30*pi/180),4]]+c2t3(arc(50,-30,0,[0,0],10))[1:-1],15)
sol12=l_extrude(sec12,300)
sol13=fillet_surf2sol(surf1,sol12,2,10,0)
sol14=q_rot(["z30"],sol12)
sol15=fillet_surf2sol(surf,sol14,2,10,0)
sol16=l_extrude(m_points(offset(sec1,-2.5),10),300)
sol17=fillet_surf2sol(surf1,sol16,2,10,1)
sol18=q_rot(["z30"],sol16)
sol19=fillet_surf2sol(surf,sol18,2,10,1)
sol20=q_rot(["z30"],sol6)
sol21=q_rot(["z30"],sol8)
sol22=q_rot(["z30"],sol10)

sec13=circle(250,s=100)
path12=cr(pts1([[-2,0],[2,0,2],[0,5,5],[-13,20,5],[0,20,5],[-12,20,5],[0,78,5],[12,20,5],[0,64,5],[13,20,5],[0,5,2],[-2,0]]),5)

sol23=prism(sec13,path12)


surf2=trns([0,0,-5],surf1)
sol24=fillet_surf2sol(surf2,sol2,1.5,10,0)
sol25=fillet_surf2sol(flip(surf2),sol16,2,10,0)
sol26=fillet_surf2sol(flip(surf2),sol12,2,10,1)

surf3=trns([0,0,-5],surf)
sol27=fillet_surf2sol(flip(surf3),sol18,2,10,0)
sol28=fillet_surf2sol(flip(surf3),sol14,2,10,1)

cyl2=cylinder(r=10,h=300,cp=[110*cos(15*pi/180),110*sin(15*pi/180)],s=50)
sol29=[ip_surf(surf3,cyl2)+[ip_surf(surf3,cyl2)[0]]]+ipe(surf3,cyl1,2,10,0)
sol05=trns([50*cos(15*pi/180),50*sin(15*pi/180),0],l_extrude(m_points(offset(sec6,-5),10),300))

sol30=[ip_surf(surf3,sol05)+[ip_surf(surf3,sol05)[0]]]+ipe(surf3,sol5,2,10,0)
sol31=ipe(surf2,sol3,2,10,0)


with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+') as f:
    f.write(f'''
    
    render(){{
    
    // spoke 1
    
    for(i=[0:60:300])rotate([0,0,i])
    difference(){{
    difference(){{
    intersection(){{
    {swp(surf_extrudef(surf_extrude(sec,path),-5))}
    {swp(sol4)}
    {swp(sol7)}
    }}
    {swp(sol5)}
    {swp(cyl1)}
    
    }}
    {swp(flip(ipe(surf3,cyl1,2,10,0)))}
    {swp(flip(ipe(surf3,sol5,2,10,0)))}
    
    }}
    
    intersection(){{
        {{for(i=[0:60:360-60])
        rotate([0,0,i])
        {swp_c(sol19)}}}
        {swp(sol7)}
      }}
     
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol15)}
    
    intersection(){{
    {{for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol27)}}}
    {swp(sol7)}
      }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol28)}
      
    for(i=[0:60:300])rotate([0,0,i])
    intersection(){{
    {swp_c(bead2)}
    {swp(sol7)}
        }}
        
    for(i=[0:60:300])rotate([0,0,i]){{
    {swp_c(bead3)}
    }}
    
    // spoke 2
    
    intersection(){{
    {{for(i=[0:60:300])rotate([0,0,i])
    difference(){{
    intersection(){{
    {swp(surf_extrudef(surf_extrude(sec10,path10),-5))}
    {swp(sol1)}
    
    }}
    {swp(sol2)}
    {swp(flip(sol31))}
    }}}}
    {swp(sol7)}
    }}

    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp(bead1)}
    {swp(sol7)}
    }}

    for(i=[0:60:360-60])
    rotate([0,0,i]){{
    intersection(){{
    {swp_c(sol25)}
    {swp(sol7)}
    }}
    {swp_c(sol26)}
    }}
    
    for(i=[0:60:360-60])
    rotate([0,0,i])
    {swp_c(sol13)}

    for(i=[0:60:360-60])
    rotate([0,0,i])
    intersection(){{
    {swp_c(sol17)}
    {swp(sol7)}
    }}
    
    // spoke 3
    for(i=[0:30:360-30])
    rotate([0,0,i])
    intersection(){{
    {swp(sol6)}
    {swp(sol7)}
    }}
    
    for(i=[0:30:360-30])
    rotate([0,0,i]){{
    {swp_c(sol8)}
    {swp_c(sol10)}
    }}
    
    // hub
    difference(){{
    {swp(sol9)}
    {swp(cylinder(r=20,h=300,s=72))}
    
    }}
    
    // rim
    {swp_c(swp_prism_h(sol23,sol7))}    
    
    
    }}
    
    ''')    
final_time=time.time()
final_time-initial_time
# Out:
# 19.50736689567566
