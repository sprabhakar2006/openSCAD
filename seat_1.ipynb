# %%
from openscad1 import *

# %%
p0,p1,p2=[0,775],[0,480],[480/sin(d2r(60))*cos(d2r(60)),0]
p3=array(p2)+[420,0]
p4=p3+q_rot2d(30,[100,0])
p5=p4+q_rot2d(120,[75,0])

p0,p1,p2,p3,p4,p5
l1=p5[0]-(p2[0]+290)
l2=320
l3=p5[1]-sqrt(l2**2-l1**2)
p6=array([p2[0]+290,l3])
p7=array(p2)+[-255,190]
l1=path_offset_n([p0,p1],-30)
# arc_1=p6+[q_rot2d(i,p5-p6) for i in linspace(0,90,30)]
# arc_1=arc_1.tolist()
p3,p4,p5,p6,p7=array([p3,p4,p5,p6,p7]).tolist()

arc_1=arc_with_start_pt_and_cp(p5,p6,120,50)
arc_2=arc(270,-90,180,p7,s=50)
arc_3=two_cir_tarc(arc_1,arc_2,70)

arc_4=fillet_line_circle(l1,arc_2,100,-1)
p6=arc_3[0]
p7=arc_3[-1]
p8=arc_4[-1]
p9=arc_4[0]

sec=[p0,p1,p2,p3,p4]+arc_2p(p5,p6,320,-1,50)+arc_2p(p6,p7,70,1,20)+ \
arc_2p(p7,p8,270,-1,50)+arc_2p(p8,p9,100,1,20)+equidistant_path([arc_4[0],l1[0]],20)
sec=remove_extra_points(array(sec).round(5))
sec_0=equidistant_pathc(sec,500)
sec1=c2t3(sec)
p_0=array(sec1[0])+[0,0,100]
p_1=array(sec1[1])+[0,0,180]
p_2=array(sec1[2])+[0,0,122]
p_3=array(sec1[3])+[0,0,200]
arc_01=arc_2p_3d([1,0,0],p_0,p_1,800,1,s=50)
arc_02=arc_2p_3d(nv([sec1[1],sec1[2],p_1]),p_1,p_2,750,1,s=50)
arc_03=arc_2p_3d([0,1,0],p_2,p_3,840,1,s=50)

surf_1=SurfaceFrom3LinesInDifferentPlanes(extend_arc3d(arc_03,15),flip(arc_02),extend_arc3d(flip(arc_01),10))

l_1=extend_arc3d(flip(surf_1[0]),10)
l_2=cpo(surf_1)[-1]
l_3=extend_arc3d(flip(surf_1[-1]),10)
surf_1=SurfaceFrom3LinesInDifferentPlanes(l_1,l_2,l_3,s=50)
surf_2=surface_line_vector(c2t3(sec[4:6]),[0,0,250],1)
surf_3=surface_line_vector(c2t3(sec[2:4]),[0,0,250],1)
sec_1=c2t3(bezier(pts([[0,0],[50,0],[50,-50],[50,0],[50,50],[50,0]]),30))
sec_1_1=mirror(sec_1,[1,0,0],[0,0,0])
sec_1=flip(sec_1_1)+sec_1[1:]
sec_1=q_rot(['y90','z30'],sec_1)
sec_1=translate(sec[5],sec_1)
sec_1=translate(q_rot(['z300'],[30,0,0]),sec_1)
l_1=project_line_on_surface(sec_1,surf_2,q_rot(['z30'],[1,0,0]))
l_2=project_line_on_surface(sec_1,surf_3,q_rot(['z30'],[1,0,0]))
surf_4=cpo(slice_sol([l_2,l_1],10))
l_3=ip_sol2sol(surf_1,surf_4)
surf_4=surf_4[6:-6]
surf_1_1=mirror_surface(surf_1,[0,0,1],[0,0,0])
surf_x=slice_surfaces(surf_1,surf_1_1,len(surf_4)-1)
surf_4=cpo([project_line_on_surface(surf_4[i],surf_x[i],[0,0,1]) for i in range(len(surf_4))])
surf_5=[path_offset_3d(p,30) for p in surf_4]
l_1=arc_2p_3d([0,1,0],p_2,mirror([p_2],[0,0,1],[0,0,0])[0],150,-1,s=45)
surf_6=cpo(slice_sol([l_1,surf_4[0]],10))
surf_6=[project_line_on_surface(surf_6[i],surf_x[i],[0,0,1]) for i in range(len(surf_6))]
surf_6=[l_1]+cpo(surf_6)[1:]
l_1=arc_2p_3d([1,0,0],p_1,mirror([p_1],[0,0,1],[0,0,0])[0],300,1,s=45)
surf_7=cpo(slice_sol([l_1,surf_6[0]],10))
surf_7=cpo([project_line_on_surface(surf_7[i],surf_x[i],[0,0,1]) for i in range(len(surf_7))])
surf_7=[l_1]+surf_7[:-1]+[surf_6[0]]
l_1=[p_0.tolist(),mirror([p_0.tolist()],[0,0,1],[0,0,0])[0]]
l_1=equidistant_path(l_1,45)
surf_8=cpo(slice_sol([l_1,surf_7[0]],10))

surf_8=cpo([project_line_on_surface(surf_8[i],translate([-1,0,0],surf_x[i]),[0,0,1]) for i in range(len(surf_8))])
surf_8=[l_1]+surf_8[1:-1]+[surf_7[0]]

l_1=cpo(surf_8)[0]+cpo(surf_7)[0]+cpo(surf_6)[0]+cpo(surf_4)[0]
l_2=project_line_on_surface(c2t3(sec[5:]),surf_1,[0,0,1])

l_2=path2path1(l_1,flip(l_2))
surf_9=cpo(slice_sol([l_2,l_1],10))
surf_9=[project_line_on_surface(p,translate([-1,-1,0],surf_1),[0,0,1])  for p in surf_9]
surf_10=mirror_surface(surf_9,[0,0,1],[0,0,1])
surf_11=surf_8+surf_7+surf_6+surf_4
surf_12=[surf_9[i]+surf_11[i][1:-1]+flip(surf_10[i]) for i in range(len(surf_11))]
l_1,l_2,_,l_3=surf_12[9:13]
l_4,l_5,_,l_6=surf_12[20:24]
l_7,l_8,_,_,l_9=surf_12[31:36]
fillet_1=cpo(convert_3lines2fillet(l_1,l_3,l_2,s=5))[:-1]
fillet_2=cpo(convert_3lines2fillet(l_4,l_6,l_5,s=5))[:-1]
fillet_3=cpo(convert_3lines2fillet(l_7,l_9,l_8,s=5))[:-1]
surf_12=surf_12[:9]+fillet_1+surf_12[13:20]+fillet_2+surf_12[24:31]+fillet_3+surf_12[36:]
surf_12=cpo(surf_12)

l_1,_,l_2,_,_,l_3=surf_12[8:14]
l_4,_,_,l_5,_,l_6=surf_12[52:58]
fillet_1=cpo(convert_3lines2fillet(l_1,l_3,l_2,s=5))[:-1]
fillet_2=cpo(convert_3lines2fillet(l_4,l_6,l_5,s=5))[:-1]
surf_12=surf_12[:8]+fillet_1+surf_12[14:52]+fillet_2+surf_12[58:]
surf_12=cpo(surf_12)
surf_13=[path_offset_3d(p,-30) for p in surf_12]

l_1=slice_sol([cpo(surf_12)[0],cpo(surf_13)[0]],2)[1]
l_2=cpo(surf_12)[0]
l_3=cpo(surf_12)[2]
fillet_1=cpo(convert_3lines2fillet(l_3,l_1,l_2))[:-1]
l_2=cpo(surf_13)[0]
l_3=cpo(surf_13)[2]
fillet_2=cpo(convert_3lines2fillet(l_1,l_3,l_2))[:-1]
surf_01=fillet_1+fillet_2[1:]
surf_02=surface_offset(surf_01,-15)
fillet_10=solid_from_2surfaces(surf_01,surf_02)

l_1=slice_sol([cpo(surf_12)[-1],cpo(surf_13)[-1]],2)[1]
l_2=cpo(surf_12)[-1]
l_3=cpo(surf_12)[-2]
fillet_1=cpo(convert_3lines2fillet(l_3,l_1,l_2))[:-1]
l_2=cpo(surf_13)[-1]
l_3=cpo(surf_13)[-2]
fillet_2=cpo(convert_3lines2fillet(l_1,l_3,l_2))[:-1]
surf_01=fillet_1+fillet_2[1:]
surf_02=surface_offset(surf_01,15)
fillet_2=solid_from_2surfaces(surf_01,surf_02)

l_1=slice_sol([surf_13[-1],surf_12[-1]],2)[1]
l_2=surf_13[-1]
l_3=surf_13[-3]
fillet_3=cpo(convert_3lines2fillet(l_3,l_1,l_2,s=5))[:-1]
l_2=surf_12[-1]
l_3=surf_12[-3]
fillet_4=cpo(convert_3lines2fillet(l_1,l_3,l_2,s=5))[:-1]
fillet_5=cpo(fillet_3+fillet_4[1:])


sol_1=solid_from_2surfaces(surf_12[:-2],surf_13[:-2])
l_1=[p_0.tolist(),mirror([p_0.tolist()],[0,0,1],[0,0,0])[0]]
arc_10=fillet_line_circle_internal_3d(l_1,arc_01,150,-1,1,20)
arc_10=flip(arc_10)+mirror(arc_10,[0,0,1],[0,0,0])[1:]

l_2=translate([30,0,0],l_1)
l_3=project_line_on_surface(c2t3(sec[-10:]),surf_1,[0,0,1])
arc_11=fillet_line_circle_internal_3d(l_2,l_3,150,1,1,20)
arc_11=flip(arc_11)+mirror(arc_11,[0,0,1],[0,0,0])[1:]

l_1=slice_sol([arc_10,arc_11],2)[1]
l_2=translate([0,-15,0],arc_10)
fillet_20=cpo(convert_3lines2fillet(l_2,l_1,arc_10))[:-1]

l_2=translate([0,-15,0],arc_11)
# l_2=project_line_on_surface(l_2,surf_13,[1,0,0])
fillet_21=cpo(convert_3lines2fillet(l_1,l_2,arc_11))[:-1]

surf_20=cpo(fillet_20+fillet_21[1:])
surf_21=surface_offset(surf_20,-50)
sol_20=solid_from_2surfaces(surf_20,surf_21)

sec_10=flip(cpo(surf_6)[0])+surf_6[0][1:]+cpo(surf_6)[-1]+flip(surf_6[-1][:-1])
sec_10=offset_3d(sec_10,-60)
sec_10=project_line_on_surface(sec_10,surf_13,[0,1,0])
sec_11=translate([0,30,0],sec_10)
sec_12=offset_3d(sec_11,-50)
sol_30=cpo(convert_3lines2fillet_closed(sec_10,sec_12,sec_11,s=20))[:-1]

sec_10=flip(cpo(surf_4)[0])+surf_4[0][1:]+cpo(surf_4)[-1]+flip(surf_4[-1][:-1])
sec_10=project_line_on_surface(offset_3d(sec_10,-40),surf_13,q_rot(['z120'],[1,0,0]))
sec_11=project_line_on_surface(offset_3d(sec_10,-5),surf_13,q_rot(['z120'],[1,0,0]))
sec_11=translate(q_rot(['z120'],[20,0,0]),sec_11)
sec_12=translate(q_rot(['z120'],[20,0,0]),sec_10)
sol_31=cpo(convert_3lines2fillet_closed(sec_10,sec_11,sec_12,s=20))[:-1]

sec_10=flip(cpo(surf_7)[0])+surf_7[0][1:]+cpo(surf_7)[-1]+flip(surf_7[-1][:-1])
sec_10=project_line_on_surface(offset_3d(sec_10,-70),surf_13,q_rot(['z30'],[1,0,0]))
sec_11=project_line_on_surface(offset_3d(sec_10,-80),surf_13,q_rot(['z30'],[1,0,0]))
sec_11=translate(q_rot(['z30'],[40,0,0]),sec_11)
sec_12=translate(q_rot(['z30'],[30,0,0]),sec_10)
sol_32=cpo(convert_3lines2fillet_closed(sec_10,sec_11,sec_12,s=20))[:-1]

sec_10=arc_10+flip(surf_8[-1])
sec_10=offset_3d(sec_10,-60)
sec_10=project_line_on_surface(sec_10,surf_13,[1,0,0])
sec_11=translate([20,0,0],sec_10)
sec_12=offset_3d(sec_11,-30)
sol_33=cpo(convert_3lines2fillet(sec_10,sec_12,sec_11,s=20))[:-1]


sec_20=sec[2:-100]
l_1=path_offset(sec_20[:2],-65)
l_2=path_offset(sec_20[3:],-30)
sec_20=c2t3(equidistant_pathc(l_1+l_2,50))
sec_21=project_line_on_surface(sec_20,cpo(cpo(surf_13)[:20]),[0,0,1])
sec_22=translate([0,0,-20],sec_21)
sec_23=offset_3d(sec_20,-5)
sec_23=project_line_on_surface(sec_23,cpo(cpo(surf_13)[:20]),[0,0,1])
sec_23=translate([0,0,-20],sec_23)
sol_40=convert_3lines2fillet_closed(sec_21,sec_23,sec_22,s=20)
sol_40=cpo(sol_40)[:-1]

sec_21=project_line_on_surface(sec_20,cpo(cpo(surf_13)[-20:]),[0,0,1])
sec_22=translate([0,0,20],sec_21)
sec_23=offset_3d(sec_20,-5)
sec_23=project_line_on_surface(sec_23,cpo(cpo(surf_13)[-20:]),[0,0,1])
sec_23=translate([0,0,20],sec_23)
sol_41=convert_3lines2fillet_closed(sec_21,sec_23,sec_22,s=20)
sol_41=cpo(sol_41)[:-1]

l_1=path_offset(equidistant_path(sec[1:3],10)[2:-2],-30)
l_2=path_offset(sec[-95:-40],-30)

sec_20=c2t3(equidistant_pathc(l_1+l_2,50))
sec_21=project_line_on_surface(sec_20,cpo(cpo(surf_13)[:20]),[0,0,1])
sec_22=translate([0,0,-20],sec_21)
sec_23=offset_3d(sec_20,-5)
sec_23=project_line_on_surface(sec_23,cpo(cpo(surf_13)[:20]),[0,0,1])
sec_23=translate([0,0,-20],sec_23)
sol_42=convert_3lines2fillet_closed(sec_21,sec_23,sec_22,s=20)
sol_42=cpo(sol_42)[:-1]

sec_21=project_line_on_surface(sec_20,cpo(cpo(surf_13)[-20:]),[0,0,1])
sec_22=translate([0,0,20],sec_21)
sec_23=offset_3d(sec_20,-5)
sec_23=project_line_on_surface(sec_23,cpo(cpo(surf_13)[-20:]),[0,0,1])
sec_23=translate([0,0,20],sec_23)
sol_43=convert_3lines2fillet_closed(sec_21,sec_23,sec_22,s=20)
sol_43=cpo(sol_43)[:-1]

with open('trial.scad','w+') as f:
    f.write(f'''
    include<dependencies2.scad>

rotate([90,0,0])
union(){{
difference(){{
union(){{
    {swp(flip(sol_1))}
    {swp(fillet_5)}
    }}
    {swp(fillet_10)}
    {swp(flip(fillet_2))}
{swp(sol_20)}
    }}
   {swp(sol_30)}
   {swp(sol_31)}
   {swp(sol_32)}
   {swp(sol_33)}
    {swp(sol_40)}
    {swp(sol_41)}
    {swp(sol_42)}
    {swp(sol_43)}
   }}
   
    
    ''')
