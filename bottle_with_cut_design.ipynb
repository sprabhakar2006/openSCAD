# %%
t0=time.time()
sec=circle(10)
path=cr(pts1([[-3,0,0],[3,0,3],[3,5,7],[-5,20,100],[8,30,20],[-11,10,5],[0,10,0]]),10)
path1=path+flip(path_offset(path,-.9))
sec1=cr(pts1([[-5,0,3],[10,0,3],[0,20,4],[-3,20,4],[0,10,2],[-4,0,2],[0,-10,4],[-3,-20,3]]),10)

sol1=q_rot(['z90'],prism(sec,path))
sol2=trns([0,0,5],q_rot(['x90','z90'],l_extrude(m_points(sec1,2),30)))
sol3=cpo(ipfillet(sol1,flip(sol2),1,10,1))[1:]
sol3=[trns([2,0,0],sol3[0])]+sol3
sol4=flip(trns([-1,0,0],cpo(ipfillet(sol1,sol2,1,10,1))[1:]))
sol5=flip(sol3+sol4+[trns([-2,0,0],sol4[len(sol4)-1])])
sol6=prism(sec,path1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies.scad>

render(){{
difference(){{
{swp(sol1)}
for(i=[0:360/4:359])
rotate([0,0,i])
translate([.1,0,0])
intersection(){{
{swp(sol5)}
{swp(sol6)}
}}
}}
}}

    ''')
t1=time.time()
t1-t0

# %%
# method2

t0=time.time()
sec=circle(10)
path=cr(pts1([[-3,0,0],[3,0,3],[3,5,7],[-5,20,100],[8,30,20],[-11,10,5],[0,10,0]]),10)
path1=path+flip(path_offset(path,-.9))
sec1=cr(pts1([[-5,0,3],[10,0,3],[0,20,4],[-3,20,4],[0,10,2],[-4,0,2],[0,-10,4],[-3,-20,3]]),10)

sol1=q_rot(['z0'],prism(sec,path))
sol2=trns([0,0,5],q_rot(['x90','z90'],l_extrude(m_points(sec1,1.1),30)))
sol3=cpo(ipf(sol1,flip(sol2),1,10,1))[1:]
sol3=sol3+[trns([2,0,0],sol3[len(sol3)-1])]
sol4=flip(trns([-1,0,0],cpo(ipf(sol1,sol2,1,10,1))[1:]))
sol5=[trns([-2,0,0],sol4[0])]+sol4+sol3
# sol5=flip(sol3+sol4+[trns([-2,0,0],sol4[len(sol4)-1])])
sol6=prism(sec,path1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies.scad>

render(){{
difference(){{
{swp(sol1)}
for(i=[0:360/4:359])
rotate([0,0,i])
translate([0.03,0,0])
intersection(){{
{swp(sol5)}
{swp(sol6)}
}}
}}
}}

    ''')
t1=time.time()
t1-t0

# %%
# method3

t0=time.time()
sec=circle(10)
path=cr(pts1([[-3,0,0],[3,0,3],[3,5,7],[-5,20,100],[8,30,20],[-11,10,5],[0,10,0]]),10)
path1=path+flip(path_offset(path,-.9))
sec1=cr(pts1([[-5,0,3],[10,0,3],[0,20,4],[-3,20,4],[0,10,2],[-4,0,2],[0,-10,4],[-3,-20,3]]),10)

sol1=q_rot(['z0'],prism(sec,path))
sol2=trns([0,0,5],q_rot(['x90','z90'],l_extrude(m_points(sec1,1.1),30)))
sol3=cpo(fillet_sol2sol(sol1,flip(sol2),1,10,0))[1:]
sol3=sol3+[trns([2,0,0],sol3[len(sol3)-1])]
sol4=flip(trns([-1,0,0],cpo(fillet_sol2sol(sol1,sol2,1,10,1))[1:]))
sol5=[trns([-2,0,0],sol4[0])]+sol4+sol3
# sol5=flip(sol3+sol4+[trns([-2,0,0],sol4[len(sol4)-1])])
sol6=prism(sec,path1)

with open('/Users/sanjeevprabhakar/iCloud Drive (Archive)/Documents/Download/openscad/trial.scad','w+')as f:
    f.write(f'''
include<dependencies.scad>

render(){{
difference(){{
{swp(sol1)}
for(i=[0:360/4:359])
rotate([0,0,i])
translate([0.03,0,0])
intersection(){{
{swp(sol5)}
{swp(sol6)}
}}
}}
}}

    ''')
t1=time.time()
t1-t0
